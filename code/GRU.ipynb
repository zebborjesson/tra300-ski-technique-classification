# %% [markdown]
# Import libraries

# %%
import os
import pandas as pd
from sklearn.preprocessing import StandardScaler, LabelEncoder
import torch, re
import torch.nn as nn
import torch.optim as optim
torch.manual_seed(42)
from sklearn.metrics import (
    accuracy_score, f1_score, classification_report, confusion_matrix, top_k_accuracy_score
)
import matplotlib
#matplotlib.use('TkAgg')  # or 'MacOSX' if on macOS
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split

# %% [markdown]
# Read data

# %%
###VALDIATION AND TRAINING DATA
TRAINING_FOLDER = "/Users/robinoscarsson/PycharmProjects/tra300-ski-technique-classification/data_sync/outputs/Training_and_validation_set/NR"

csv_files = [f for f in os.listdir(TRAINING_FOLDER) if f.endswith('.csv')]

dataframes = {}
for file in csv_files:
    full_path = os.path.join(TRAINING_FOLDER, file)
    df = pd.read_csv(full_path)
    dataframes[file] = df

# %%
###TEST DATA
TEST_FOLDER = "/Users/robinoscarsson/PycharmProjects/tra300-ski-technique-classification/data_sync/outputs/Test_set/NR"

csv_files = [f for f in os.listdir(TEST_FOLDER) if f.endswith('.csv')]
dataframes_test = {}
for file in csv_files:
    full_path = os.path.join(TEST_FOLDER, file)
    df = pd.read_csv(full_path)
    dataframes_test[file] = df

print(f"test data files {dataframes_test.keys()}")
# Out:
# test data files dict_keys(['BIA24-22_NR_merged_with_gear.csv', 'BIA24-5_NR_merged_with_gear.csv'])

# %%
####
input_cols_poles = ["frequency_ppm", "thrust_left_ms", "thrust_right_ms", "impulse_left_ns", "impulse_right_ns", "force_meanl_n", "force_meanr_n", "f_tot_mean_n"] #ADD columns from avaialble ones if needed
GNNS_poles = ['ns1:AltitudeMeters', 'ns2:Speed', 'ns2:RunCadence', 'ns2:Watts']
output_cols = ["Gear"]
input_cols = input_cols_poles + GNNS_poles

print("Loaded CSV files:")
for k in sorted(dataframes.keys()):
    print(" •", k)

# Take a sample frame to list columns
_sample_key = next(iter(dataframes))
print("\nColumns in sample file:", _sample_key)
print(list(dataframes[_sample_key].columns))

print("\nUsing inputs:", input_cols)
print("Using output:", output_cols)
# Out:
# Loaded CSV files:
#  • BIA24-15_NR_merged_with_gear.csv
#  • BIA24-16_NR_merged_with_gear.csv
#  • BIA24-18_NR_merged_with_gear.csv
#  • BIA24-19_NR_merged_with_gear.csv
#  • BIA24-20_NR_merged_with_gear.csv
#  • BIA24-3_NR_merged_with_gear.csv
#  • BIA24-4_NR_merged_with_gear.csv
#  • BIA24-7_NR_merged_with_gear.csv
#  • BIA24-8_NR_merged_with_gear.csv
#  • BIA24-9_NR_merged_with_gear.csv
#
# Columns in sample file: BIA24-8_NR_merged_with_gear.csv
# ['tt_s', 'Lap', 'Gear', 'ns1:LatitudeDegrees', 'ns1:LongitudeDegrees', 'Sport', 'speed_kmph', 'power_w', 'frequency_ppm', 'thrust_left_ms', 'thrust_right_ms', 'impulse_left_ns', 'impulse_right_ns', 'force_meanl_n', 'force_meanr_n', 'f_tot_mean_n', 'ns1:AltitudeMeters', 'ns2:Speed', 'ns2:RunCadence', 'ns2:Watts']
#
# Using inputs: ['frequency_ppm', 'thrust_left_ms', 'thrust_right_ms', 'impulse_left_ns', 'impulse_right_ns', 'force_meanl_n', 'force_meanr_n', 'f_tot_mean_n', 'ns1:AltitudeMeters', 'ns2:Speed', 'ns2:RunCadence', 'ns2:Watts']
# Using output: ['Gear']

# %%
#Split into train/test dataframes and make sure there are no NA
train_keys = [k for k in dataframes.keys()]
test_keys = [k for k in dataframes_test.keys()]

train_df_full = pd.concat([dataframes[k] for k in train_keys], ignore_index=True) # Renamed
test_df = pd.concat([dataframes_test[k] for k in test_keys], ignore_index=True) # Renamed

needed_cols = list(set(input_cols + output_cols))
train_df_full = train_df_full.dropna(subset=needed_cols).reset_index(drop=True)
test_df = test_df.dropna(subset=needed_cols).reset_index(drop=True)

# %%
# Normalize labels: "2.0H" / "2.0V" / "2.0" -> "2.0"
label_col = output_cols[0]

def normalize_label(val: object) -> str:
    s = str(val).strip()
    m = re.search(r'^-?\d+(?:\.\d+)?', s) # take leading number (int or float)
    if m:
        return f"{float(m.group(0)):.1f}" # standardize format, e.g., 2 -> "2.0"
    return s # fall back to original string

train_df_full[label_col] = train_df_full[label_col].apply(normalize_label)
test_df[label_col] = test_df[label_col].apply(normalize_label)

# %%
# Create Train/Validation SpliT
# We split the full training data into a new (smaller) training set
# and a validation set.

try:
    train_df, val_df = train_test_split(
        train_df_full,
        test_size=0.2, # 20% for validation
        random_state=42,
        stratify=train_df_full[label_col] # Keep class distribution in splits
    )
except ValueError:
    print("Warning: Could not stratify split (likely due to rare classes). Splitting without stratification.")
    train_df, val_df = train_test_split(
        train_df_full,
        test_size=0.2, # 20% for validation
        random_state=42
    )

# %%
###Encode labels and make sure they are represented everywhere

# Encode labels using ALL labels (train_full + test) to avoid unseen-label errors
label_encoder = LabelEncoder()

#Concentenate to get one long list of labels in the
all_labels = pd.concat(
    [train_df_full[label_col], test_df[label_col]], # Use train_df_full here
    ignore_index=True
)
#Makes all lables which are strings into integers (in this case it is just e.g "1.0" -> 1
label_encoder.fit(all_labels)

###NOW TURN COLUMNS IN DATAFRAMES OF LABELS INTO THIS MAPPING (I.E into integers
y_train = label_encoder.transform(train_df[label_col]) # Use new train_df
y_val = label_encoder.transform(val_df[label_col])     # Create y_val
y_test = label_encoder.transform(test_df[label_col])
num_classes = len(label_encoder.classes_)


###Sanity check to make sure or chosen test files don't contain gears that don't exist in other sets
#create python sets of classes found in all data sets
train_classes = set(np.unique(y_train))
val_classes = set(np.unique(y_val))
test_classes = set(np.unique(y_test))

#If any class is only in test creating warning
only_in_test = sorted(list(test_classes - train_classes - val_classes))
if only_in_test:
    names_only_in_test = [label_encoder.classes_[i] for i in only_in_test]
    print("⚠️ These classes exist only in TEST (not seen in train/val):", names_only_in_test)

# %%
# Prepare inputs in terms of each timestep
X_train = train_df[input_cols].values.astype(np.float32)
X_val = val_df[input_cols].values.astype(np.float32)     # Create X_val
X_test = test_df[input_cols].values.astype(np.float32)

# ---- Convert to PyTorch tensors ----
X_train_t = torch.tensor(X_train, dtype=torch.float32)
X_val_t = torch.tensor(X_val, dtype=torch.float32)   # Create X_val_t
X_test_t = torch.tensor(X_test, dtype=torch.float32)

y_train_t = torch.tensor(y_train, dtype=torch.long)
y_val_t = torch.tensor(y_val, dtype=torch.long)     # Create y_val_t
y_test_t = torch.tensor(y_test, dtype=torch.long)

print(X_train_t.shape)
# Out:
# torch.Size([9016, 12])

# %%
###MAKE TENSOR DATA INTO SEQUENCES FOR RNN (IGNORE FOR NON SEQUENTIAL ARCHITECTURES)

SEQ_LEN = 10    # length of each sequence in seconds (samples)
STRIDE = 2      # how much to slide the window forward

def make_sequences(X_t, y_t, seq_len=SEQ_LEN, stride=STRIDE):
    """
    #Turn flat sensor data (N x features) into overlapping sequences for RNNs.
    """
    X_seq, y_seq = [], []
    for i in range(0, len(X_t) - seq_len + 1, stride):
        X_seq.append(X_t[i:i+seq_len])
        y_seq.append(y_t[i:i+seq_len])
    X_seq = torch.stack(X_seq)      # shape: (num_sequences, seq_len, num_features)
    y_seq = torch.stack(y_seq)      # shape: (num_sequences,)
    return X_seq, y_seq

# Apply to train, val, and test
X_train_seq, y_train_seq = make_sequences(X_train_t, y_train_t)
X_val_seq, y_val_seq     = make_sequences(X_val_t, y_val_t)
X_test_seq, y_test_seq   = make_sequences(X_test_t, y_test_t)
print(y_train_seq.shape)
print(f"X_train_seq shape: {X_train_seq.shape}")
print(f"X_val_seq shape:   {X_val_seq.shape}")
print(f"X_test_seq shape:  {X_test_seq.shape}")
# Out:
# torch.Size([4504, 10])
# X_train_seq shape: torch.Size([4504, 10, 12])
# X_val_seq shape:   torch.Size([1123, 10, 12])
# X_test_seq shape:  torch.Size([1205, 10, 12])

# %%
#### WEIGHT Class weights (based on new, smaller training set)

input_dim = X_train_seq.shape[2]
output_dim = num_classes
print(input_dim)
counts_np = np.bincount(y_train_seq.reshape(-1) , minlength=num_classes)
class_counts = torch.tensor(counts_np, dtype=torch.float32)
with torch.no_grad():
    class_weights = torch.where(class_counts > 0, 1.0 / class_counts, torch.tensor(0.0))
    nz = class_weights > 0
    if nz.any():
        class_weights[nz] = class_weights[nz] * (nz.sum() / class_weights[nz].sum())

print(f"The amount of inputs: Train size: {len(X_train_seq)} | Val size: {len(X_val_seq)} | Test size: {len(X_test_seq)}")
print(f"Input dim: {input_dim} | Classes: {num_classes}")
print("Label mapping (int -> original):")
for i, name in enumerate(label_encoder.classes_):
    print(f"  {i} -> {name}")
print("Training Class counts (amount of gears):", counts_np.tolist())
print(f"the weights are {class_weights}")
# Out:
# 12
# The amount of inputs: Train size: 4504 | Val size: 1123 | Test size: 1205
# Input dim: 12 | Classes: 4
# Label mapping (int -> original):
#   0 -> 0.0
#   1 -> 2.0
#   2 -> 3.0
#   3 -> 4.0
# Training Class counts (amount of gears): [8981, 6700, 23462, 5897]
# the weights are tensor([0.9420, 1.2627, 0.3606, 1.4347])

# %%
###HELPER FUNCTIONS

def _stable_indices(y, n=2):
    """Return positional indices where the label has been stable for n before and n after."""
    y = y.reset_index(drop=True)
    idx = []
    for i in range(n, len(y) - n):
        c = y.iloc[i]
        # use iloc for positional comparisons
        if all(y.iloc[i - j] == c and y.iloc[i + j] == c for j in range(1, n + 1)):
            idx.append(i)
    return idx

def accuracy_when_stable_gear(y, pred, n=2):
    """Accuracy only on timesteps where the gear is stable for n steps before & after."""
    y = y.reset_index(drop=True)
    pred = np.asarray(pred)
    idx = _stable_indices(y, n)
    if len(idx) == 0:
        return np.nan
    return np.mean(y.iloc[idx].values == pred[idx])

def classification_report_when_stable_gear(y, pred, n=2):
    """Sklearn classification_report restricted to stable gear timesteps."""
    y = y.reset_index(drop=True)
    pred = np.asarray(pred)
    idx = _stable_indices(y, n)
    if len(idx) == 0:
        return "No stable segments found."
    return classification_report(y.iloc[idx], pred[idx], labels=ALL_LABELS, zero_division=0)

def confusion_matrix_when_stable_gear(y, pred, n=2):
    """Confusion matrix restricted to stable gear timesteps."""
    y = y.reset_index(drop=True)
    pred = np.asarray(pred)
    idx = _stable_indices(y, n)
    if len(idx) == 0:
        return None
    return confusion_matrix(y.iloc[idx], pred[idx], labels=ALL_LABELS)


def plot_training(epochs, train_losses, val_losses):
    """Plot the training and validation losses."""
    plt.plot(range(epochs), train_losses, label="Training Loss")
    plt.plot(range(epochs), val_losses, "--", label="Validation Loss")
    plt.xlabel("Epoch"), plt.xlim([0, epochs - 1])
    plt.ylabel("Loss")
    plt.legend()
    plt.show()


def plot_training(epochs, train_losses, val_losses):
    """Plot the training and validation losses."""
    plt.plot(range(epochs), train_losses, label="Training Loss")
    plt.plot(range(epochs), val_losses, "--", label="Validation Loss")
    plt.xlabel("Epoch"), plt.xlim([0, epochs - 1])
    plt.ylabel("Loss")
    plt.legend()
    plt.show()

def batches(X, y, batch_size, shuffle=True):
    n = len(X)
    idx = np.arange(n)

    #We don't want to shuffle for validation and training
    if shuffle:
        np.random.shuffle(idx)
    for start in range(0, n, batch_size):
        end = start + batch_size
        sel = idx[start:end]
        yield X[sel], y[sel]

# Source - https://stackoverflow.com/a
# Posted by isle_of_gods, modified by community. See post 'Timeline' for change history
# Retrieved 2025-11-12, License - CC BY-SA 4.0
class EarlyStopper:
    def __init__(self, patience=5, min_delta= 1e-3):
        self.patience = patience
        self.min_delta = min_delta
        self.counter = 0
        self.min_validation_loss = float('inf')

    def early_stop(self, validation_loss):
        if validation_loss < self.min_validation_loss:
            self.min_validation_loss = validation_loss
            self.counter = 0
        elif validation_loss > (self.min_validation_loss + self.min_delta):
            self.counter += 1
            if self.counter >= self.patience:
                return True
        return False

# %% [markdown]
# GRU architecture

# %%
####ARCHITECTURE
EPOCHS = 150
BATCH_SIZE = 256
PRINT_EVERY = 1
hidden_size = 32

model = nn.GRU(input_size=input_dim, hidden_size=hidden_size, num_layers=3, batch_first=True, dropout=0.2)
fc = nn.Linear(hidden_size, output_dim)  # Map hidden state → class logits
criterion = nn.CrossEntropyLoss(weight=class_weights)
optimizer = optim.Adam(model.parameters(), lr=1e-3, weight_decay=1e-5)

# %%
### Training loop
history = {'train_loss': [], 'val_loss': [], 'val_acc': []}

print("Starting training...")
early_stopper = EarlyStopper(patience=5, min_delta=0.05)
#in case early stopping
epoch_counter = 1

for epoch in range(1, EPOCHS + 1):
    # --- Training Phase ---
    model.train()
    fc.train()

    running_loss = 0.0
    total_train_samples = 0

    for Xb, yb in batches(X_train_seq, y_train_seq, BATCH_SIZE):
        optimizer.zero_grad()

        # Forward pass
        out, _ = model(Xb)          # out: (batch, seq_len, hidden)
        logits = fc(out)            # logits: (batch, seq_len, num_classes)

        # Flatten batch + sequence dims
        loss = criterion(
            logits.reshape(-1, output_dim),   # (batch*seq_len, C)
            yb.reshape(-1)                    # (batch*seq_len)
        )

        # Backprop
        loss.backward()
        optimizer.step()

        running_loss += loss.item() * Xb.size(0) * Xb.size(1)  # multiply by seq_len
        total_train_samples += Xb.size(0) * Xb.size(1)

    avg_train_loss = running_loss / total_train_samples
    history['train_loss'].append(avg_train_loss)

    # --- Validation Phase ---
    model.eval()
    fc.eval()

    val_loss = 0.0
    val_correct = 0
    total_val_samples = 0

    with torch.no_grad():
        for Xb, yb in batches(X_val_seq, y_val_seq, BATCH_SIZE, shuffle=False):

            out, _ = model(Xb)           # (batch, seq_len, hidden)
            logits = fc(out)             # (batch, seq_len, num_classes)

            # Loss over all timesteps
            loss = criterion(
                logits.reshape(-1, output_dim), #Gives us [batch* seq_length, num_classes]
                yb.reshape(-1)
            )

            val_loss += loss.item() * Xb.size(0) * Xb.size(1)

            # Predictions for accuracy
            preds = logits.argmax(dim=2)      # (batch, seq_len)
            val_correct += (preds == yb).sum().item()
            total_val_samples += yb.numel()

    avg_val_loss = val_loss / total_val_samples
    val_accuracy = val_correct / total_val_samples
    history['val_loss'].append(avg_val_loss)
    history['val_acc'].append(val_accuracy)

    # --- Print Epoch Stats ---
    if epoch % PRINT_EVERY == 0:
        print(f"Epoch {epoch:03d} | Train loss: {avg_train_loss:.4f} | Val loss: {avg_val_loss:.4f} | Val Acc: {val_accuracy:.4f}")

    if early_stopper.early_stop(avg_val_loss):
        print("Early stopping")
        break

    epoch_counter += 1

if epoch_counter<EPOCHS:
    plot_training(epoch_counter, history['train_loss'], history['val_loss'])
else:
    plot_training(EPOCHS, history['train_loss'], history['val_loss'])

    # --- (Removed "Save Best Model" block) ---

print("Training finished.")

# --- (Removed "Load Best Model" block) ---
print("\nUsing model state from final epoch for evaluation.")
# Out:
# Starting training...
# Epoch 001 | Train loss: 1.3765 | Val loss: 1.3602 | Val Acc: 0.3061
# Epoch 002 | Train loss: 1.3331 | Val loss: 1.2900 | Val Acc: 0.3402
# Epoch 003 | Train loss: 1.2229 | Val loss: 1.1326 | Val Acc: 0.4270
# Epoch 004 | Train loss: 1.0672 | Val loss: 1.0034 | Val Acc: 0.4640
# Epoch 005 | Train loss: 0.9667 | Val loss: 0.9293 | Val Acc: 0.5075
# Epoch 006 | Train loss: 0.9046 | Val loss: 0.8753 | Val Acc: 0.5475
# Epoch 007 | Train loss: 0.8573 | Val loss: 0.8330 | Val Acc: 0.6030
# Epoch 008 | Train loss: 0.8196 | Val loss: 0.8017 | Val Acc: 0.6443
# Epoch 009 | Train loss: 0.7919 | Val loss: 0.7779 | Val Acc: 0.6666
# Epoch 010 | Train loss: 0.7695 | Val loss: 0.7586 | Val Acc: 0.6857
# Epoch 011 | Train loss: 0.7515 | Val loss: 0.7430 | Val Acc: 0.7073
# Epoch 012 | Train loss: 0.7350 | Val loss: 0.7310 | Val Acc: 0.7141
# Epoch 013 | Train loss: 0.7228 | Val loss: 0.7189 | Val Acc: 0.7269
# Epoch 014 | Train loss: 0.7096 | Val loss: 0.7092 | Val Acc: 0.7386
# Epoch 015 | Train loss: 0.7005 | Val loss: 0.7006 | Val Acc: 0.7351
# Epoch 016 | Train loss: 0.6911 | Val loss: 0.6914 | Val Acc: 0.7446
# Epoch 017 | Train loss: 0.6854 | Val loss: 0.6847 | Val Acc: 0.7447
# Epoch 018 | Train loss: 0.6777 | Val loss: 0.6779 | Val Acc: 0.7432
# Epoch 019 | Train loss: 0.6716 | Val loss: 0.6729 | Val Acc: 0.7428
# Epoch 020 | Train loss: 0.6653 | Val loss: 0.6670 | Val Acc: 0.7411
# Epoch 021 | Train loss: 0.6609 | Val loss: 0.6626 | Val Acc: 0.7500
# Epoch 022 | Train loss: 0.6553 | Val loss: 0.6577 | Val Acc: 0.7570
# Epoch 023 | Train loss: 0.6511 | Val loss: 0.6542 | Val Acc: 0.7539
# Epoch 024 | Train loss: 0.6466 | Val loss: 0.6516 | Val Acc: 0.7545
# Epoch 025 | Train loss: 0.6429 | Val loss: 0.6498 | Val Acc: 0.7522
# Epoch 026 | Train loss: 0.6416 | Val loss: 0.6455 | Val Acc: 0.7588
# Epoch 027 | Train loss: 0.6373 | Val loss: 0.6436 | Val Acc: 0.7654
# Epoch 028 | Train loss: 0.6347 | Val loss: 0.6419 | Val Acc: 0.7584
# Epoch 029 | Train loss: 0.6316 | Val loss: 0.6419 | Val Acc: 0.7577
# Epoch 030 | Train loss: 0.6314 | Val loss: 0.6406 | Val Acc: 0.7623
# Epoch 031 | Train loss: 0.6284 | Val loss: 0.6392 | Val Acc: 0.7683
# Epoch 032 | Train loss: 0.6244 | Val loss: 0.6368 | Val Acc: 0.7613
# Epoch 033 | Train loss: 0.6246 | Val loss: 0.6371 | Val Acc: 0.7637
# Epoch 034 | Train loss: 0.6224 | Val loss: 0.6363 | Val Acc: 0.7598
# Epoch 035 | Train loss: 0.6208 | Val loss: 0.6330 | Val Acc: 0.7676
# Epoch 036 | Train loss: 0.6169 | Val loss: 0.6335 | Val Acc: 0.7660
# Epoch 037 | Train loss: 0.6193 | Val loss: 0.6333 | Val Acc: 0.7617
# Epoch 038 | Train loss: 0.6158 | Val loss: 0.6307 | Val Acc: 0.7670
# Epoch 039 | Train loss: 0.6120 | Val loss: 0.6303 | Val Acc: 0.7685
# Epoch 040 | Train loss: 0.6115 | Val loss: 0.6310 | Val Acc: 0.7647
# Epoch 041 | Train loss: 0.6105 | Val loss: 0.6295 | Val Acc: 0.7654
# Epoch 042 | Train loss: 0.6094 | Val loss: 0.6283 | Val Acc: 0.7625
# Epoch 043 | Train loss: 0.6083 | Val loss: 0.6282 | Val Acc: 0.7688
# Epoch 044 | Train loss: 0.6042 | Val loss: 0.6261 | Val Acc: 0.7673
# Epoch 045 | Train loss: 0.6027 | Val loss: 0.6276 | Val Acc: 0.7619
# Epoch 046 | Train loss: 0.6011 | Val loss: 0.6253 | Val Acc: 0.7653
# Epoch 047 | Train loss: 0.6015 | Val loss: 0.6238 | Val Acc: 0.7674
# Epoch 048 | Train loss: 0.5981 | Val loss: 0.6245 | Val Acc: 0.7633
# Epoch 049 | Train loss: 0.5969 | Val loss: 0.6223 | Val Acc: 0.7711
# Epoch 050 | Train loss: 0.5961 | Val loss: 0.6241 | Val Acc: 0.7647
# Epoch 051 | Train loss: 0.5952 | Val loss: 0.6221 | Val Acc: 0.7719
# Epoch 052 | Train loss: 0.5924 | Val loss: 0.6217 | Val Acc: 0.7695
# Epoch 053 | Train loss: 0.5934 | Val loss: 0.6212 | Val Acc: 0.7723
# Epoch 054 | Train loss: 0.5913 | Val loss: 0.6220 | Val Acc: 0.7698
# Epoch 055 | Train loss: 0.5875 | Val loss: 0.6219 | Val Acc: 0.7740
# Epoch 056 | Train loss: 0.5878 | Val loss: 0.6209 | Val Acc: 0.7687
# Epoch 057 | Train loss: 0.5906 | Val loss: 0.6213 | Val Acc: 0.7728
# Epoch 058 | Train loss: 0.5843 | Val loss: 0.6206 | Val Acc: 0.7728
# Epoch 059 | Train loss: 0.5832 | Val loss: 0.6211 | Val Acc: 0.7688
# Epoch 060 | Train loss: 0.5824 | Val loss: 0.6191 | Val Acc: 0.7719
# Epoch 061 | Train loss: 0.5810 | Val loss: 0.6194 | Val Acc: 0.7710
# Epoch 062 | Train loss: 0.5808 | Val loss: 0.6217 | Val Acc: 0.7703
# Epoch 063 | Train loss: 0.5816 | Val loss: 0.6204 | Val Acc: 0.7705
# Epoch 064 | Train loss: 0.5775 | Val loss: 0.6201 | Val Acc: 0.7750
# Epoch 065 | Train loss: 0.5763 | Val loss: 0.6198 | Val Acc: 0.7697
# Epoch 066 | Train loss: 0.5754 | Val loss: 0.6203 | Val Acc: 0.7710
# Epoch 067 | Train loss: 0.5740 | Val loss: 0.6195 | Val Acc: 0.7707
# Epoch 068 | Train loss: 0.5722 | Val loss: 0.6190 | Val Acc: 0.7725
# Epoch 069 | Train loss: 0.5729 | Val loss: 0.6194 | Val Acc: 0.7744
# Epoch 070 | Train loss: 0.5689 | Val loss: 0.6198 | Val Acc: 0.7710
# Epoch 071 | Train loss: 0.5702 | Val loss: 0.6190 | Val Acc: 0.7745
# Epoch 072 | Train loss: 0.5684 | Val loss: 0.6198 | Val Acc: 0.7735
# Epoch 073 | Train loss: 0.5694 | Val loss: 0.6206 | Val Acc: 0.7702
# Epoch 074 | Train loss: 0.5656 | Val loss: 0.6191 | Val Acc: 0.7753
# Epoch 075 | Train loss: 0.5628 | Val loss: 0.6187 | Val Acc: 0.7724
# Epoch 076 | Train loss: 0.5639 | Val loss: 0.6180 | Val Acc: 0.7756
# Epoch 077 | Train loss: 0.5630 | Val loss: 0.6198 | Val Acc: 0.7735
# Epoch 078 | Train loss: 0.5620 | Val loss: 0.6205 | Val Acc: 0.7729
# Epoch 079 | Train loss: 0.5607 | Val loss: 0.6196 | Val Acc: 0.7730
# Epoch 080 | Train loss: 0.5606 | Val loss: 0.6182 | Val Acc: 0.7750
# Epoch 081 | Train loss: 0.5560 | Val loss: 0.6190 | Val Acc: 0.7729
# Epoch 082 | Train loss: 0.5563 | Val loss: 0.6198 | Val Acc: 0.7724
# Epoch 083 | Train loss: 0.5570 | Val loss: 0.6194 | Val Acc: 0.7734
# Epoch 084 | Train loss: 0.5538 | Val loss: 0.6189 | Val Acc: 0.7747
# Epoch 085 | Train loss: 0.5519 | Val loss: 0.6200 | Val Acc: 0.7721
# Epoch 086 | Train loss: 0.5538 | Val loss: 0.6201 | Val Acc: 0.7713
# Epoch 087 | Train loss: 0.5521 | Val loss: 0.6186 | Val Acc: 0.7752
# Epoch 088 | Train loss: 0.5495 | Val loss: 0.6191 | Val Acc: 0.7735
# Epoch 089 | Train loss: 0.5521 | Val loss: 0.6196 | Val Acc: 0.7723
# Epoch 090 | Train loss: 0.5494 | Val loss: 0.6203 | Val Acc: 0.7766
# Epoch 091 | Train loss: 0.5478 | Val loss: 0.6212 | Val Acc: 0.7726
# Epoch 092 | Train loss: 0.5473 | Val loss: 0.6198 | Val Acc: 0.7743
# Epoch 093 | Train loss: 0.5477 | Val loss: 0.6193 | Val Acc: 0.7770
# Epoch 094 | Train loss: 0.5456 | Val loss: 0.6198 | Val Acc: 0.7715
# Epoch 095 | Train loss: 0.5435 | Val loss: 0.6208 | Val Acc: 0.7738
# Epoch 096 | Train loss: 0.5442 | Val loss: 0.6208 | Val Acc: 0.7776
# Epoch 097 | Train loss: 0.5421 | Val loss: 0.6203 | Val Acc: 0.7726
# Epoch 098 | Train loss: 0.5402 | Val loss: 0.6214 | Val Acc: 0.7701
# Epoch 099 | Train loss: 0.5402 | Val loss: 0.6204 | Val Acc: 0.7714
# Epoch 100 | Train loss: 0.5392 | Val loss: 0.6213 | Val Acc: 0.7720
# Epoch 101 | Train loss: 0.5386 | Val loss: 0.6209 | Val Acc: 0.7712
# Epoch 102 | Train loss: 0.5372 | Val loss: 0.6212 | Val Acc: 0.7691
# Epoch 103 | Train loss: 0.5366 | Val loss: 0.6246 | Val Acc: 0.7749
# Epoch 104 | Train loss: 0.5353 | Val loss: 0.6223 | Val Acc: 0.7732
# Epoch 105 | Train loss: 0.5320 | Val loss: 0.6216 | Val Acc: 0.7677
# Epoch 106 | Train loss: 0.5316 | Val loss: 0.6230 | Val Acc: 0.7723
# Epoch 107 | Train loss: 0.5315 | Val loss: 0.6227 | Val Acc: 0.7729
# Epoch 108 | Train loss: 0.5330 | Val loss: 0.6231 | Val Acc: 0.7753
# Epoch 109 | Train loss: 0.5304 | Val loss: 0.6231 | Val Acc: 0.7717
# Epoch 110 | Train loss: 0.5299 | Val loss: 0.6235 | Val Acc: 0.7703
# Epoch 111 | Train loss: 0.5271 | Val loss: 0.6270 | Val Acc: 0.7722
# Epoch 112 | Train loss: 0.5281 | Val loss: 0.6241 | Val Acc: 0.7726
# Epoch 113 | Train loss: 0.5275 | Val loss: 0.6241 | Val Acc: 0.7726
# Epoch 114 | Train loss: 0.5255 | Val loss: 0.6234 | Val Acc: 0.7738
# Epoch 115 | Train loss: 0.5250 | Val loss: 0.6253 | Val Acc: 0.7711
# Epoch 116 | Train loss: 0.5253 | Val loss: 0.6254 | Val Acc: 0.7725
# Epoch 117 | Train loss: 0.5265 | Val loss: 0.6253 | Val Acc: 0.7706
# Epoch 118 | Train loss: 0.5245 | Val loss: 0.6254 | Val Acc: 0.7695
# Epoch 119 | Train loss: 0.5247 | Val loss: 0.6262 | Val Acc: 0.7711
# Epoch 120 | Train loss: 0.5211 | Val loss: 0.6270 | Val Acc: 0.7751
# Epoch 121 | Train loss: 0.5206 | Val loss: 0.6284 | Val Acc: 0.7693
# Epoch 122 | Train loss: 0.5178 | Val loss: 0.6275 | Val Acc: 0.7723
# Epoch 123 | Train loss: 0.5187 | Val loss: 0.6279 | Val Acc: 0.7758
# Epoch 124 | Train loss: 0.5182 | Val loss: 0.6272 | Val Acc: 0.7703
# Epoch 125 | Train loss: 0.5171 | Val loss: 0.6281 | Val Acc: 0.7719
# Epoch 126 | Train loss: 0.5182 | Val loss: 0.6268 | Val Acc: 0.7732
# Epoch 127 | Train loss: 0.5159 | Val loss: 0.6289 | Val Acc: 0.7679
# Epoch 128 | Train loss: 0.5154 | Val loss: 0.6286 | Val Acc: 0.7712
# Epoch 129 | Train loss: 0.5136 | Val loss: 0.6302 | Val Acc: 0.7680
# Epoch 130 | Train loss: 0.5150 | Val loss: 0.6309 | Val Acc: 0.7733
# Epoch 131 | Train loss: 0.5145 | Val loss: 0.6321 | Val Acc: 0.7688
# Epoch 132 | Train loss: 0.5117 | Val loss: 0.6297 | Val Acc: 0.7720
# Epoch 133 | Train loss: 0.5119 | Val loss: 0.6307 | Val Acc: 0.7681
# Epoch 134 | Train loss: 0.5102 | Val loss: 0.6310 | Val Acc: 0.7694
# Epoch 135 | Train loss: 0.5107 | Val loss: 0.6292 | Val Acc: 0.7717
# Epoch 136 | Train loss: 0.5111 | Val loss: 0.6298 | Val Acc: 0.7714
# Epoch 137 | Train loss: 0.5083 | Val loss: 0.6322 | Val Acc: 0.7729
# Epoch 138 | Train loss: 0.5081 | Val loss: 0.6318 | Val Acc: 0.7696
# Epoch 139 | Train loss: 0.5059 | Val loss: 0.6329 | Val Acc: 0.7710
# Epoch 140 | Train loss: 0.5072 | Val loss: 0.6338 | Val Acc: 0.7685
# Epoch 141 | Train loss: 0.5069 | Val loss: 0.6344 | Val Acc: 0.7667
# Epoch 142 | Train loss: 0.5054 | Val loss: 0.6320 | Val Acc: 0.7691
# Epoch 143 | Train loss: 0.5055 | Val loss: 0.6326 | Val Acc: 0.7724
# Epoch 144 | Train loss: 0.5037 | Val loss: 0.6341 | Val Acc: 0.7701
# Epoch 145 | Train loss: 0.5033 | Val loss: 0.6363 | Val Acc: 0.7639
# Epoch 146 | Train loss: 0.5027 | Val loss: 0.6336 | Val Acc: 0.7666
# Epoch 147 | Train loss: 0.5014 | Val loss: 0.6337 | Val Acc: 0.7679
# Epoch 148 | Train loss: 0.5016 | Val loss: 0.6338 | Val Acc: 0.7725
# Epoch 149 | Train loss: 0.4996 | Val loss: 0.6347 | Val Acc: 0.7671
# Epoch 150 | Train loss: 0.5004 | Val loss: 0.6338 | Val Acc: 0.7710
# Training finished.
#
# Using model state from final epoch for evaluation.

# %%
model.eval()
fc.eval()

all_preds = []
all_true = []

with torch.no_grad():
    for Xb, yb in batches(X_test_seq, y_test_seq, BATCH_SIZE, shuffle=False):

        out, _ = model(Xb)              # (batch, seq_len, hidden)
        logits = fc(out)                # (batch, seq_len, num_classes)

        preds = logits.argmax(dim=2)    # (batch, seq_len)

        all_preds.append(preds.cpu())
        all_true.append(yb.cpu())

# Concatenate along batch dimension
y_pred = torch.cat(all_preds, dim=0).numpy()   # (N, seq_len)
y_true = torch.cat(all_true, dim=0).numpy()    # (N, seq_len)

# Flatten to (N * seq_len)
y_pred_flat = y_pred.reshape(-1)
y_true_flat = y_true.reshape(-1)
# Compute accuracy
acc = accuracy_score(y_true_flat, y_pred_flat)
print(f"Test Accuracy: {acc:.4f}")

print("\nClassification report on stable segments:")
print(classification_report(y_true_flat, y_pred_flat))

# Confusion matrix
target_names = list(label_encoder.classes_)
cm = confusion_matrix(y_true_flat, y_pred_flat)

plt.figure(figsize=(6, 5))
plt.imshow(cm, interpolation='nearest', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.xticks(ticks=np.arange(len(target_names)), labels=target_names, rotation=45, ha='right')
plt.yticks(ticks=np.arange(len(target_names)), labels=target_names)

# Annotate each cell
for (i, j), v in np.ndenumerate(cm):
    plt.text(j, i, str(v), ha='center', va='center', color='black')

plt.tight_layout()
plt.show()
# Out:
# Test Accuracy: 0.8120
#
# Classification report on stable segments:
#               precision    recall  f1-score   support
#
#            0       0.78      0.87      0.82      1955
#            1       0.83      0.96      0.89      1819
#            2       0.95      0.80      0.87      7121
#            3       0.38      0.59      0.46      1155
#
#     accuracy                           0.81     12050
#    macro avg       0.73      0.80      0.76     12050
# weighted avg       0.85      0.81      0.82     12050

# %%
### stable gear test

ALL_LABELS = list(range(num_classes))
n=2

y_true_series = pd.Series(y_true_flat)

stable_acc = accuracy_when_stable_gear(y_true_series, y_pred_flat, n=n)
print(f"\nStable-gear accuracy (n=2): {stable_acc:.4f}")

print("\nClassification report on stable segments:")
print(classification_report_when_stable_gear(y_true_series, y_pred_flat, n=n))

cm_stable = confusion_matrix_when_stable_gear(y_true_series, y_pred_flat, n=n)

if cm_stable is not None:
    plt.figure(figsize=(6, 5))
    plt.imshow(cm_stable, interpolation='nearest', cmap='Blues')
    plt.title('Confusion Matrix (Stable Gear Only)')
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.xticks(ticks=np.arange(len(target_names)), labels=target_names, rotation=45, ha='right')
    plt.yticks(ticks=np.arange(len(target_names)), labels=target_names)

    for (i, j), v in np.ndenumerate(cm_stable):
        plt.text(j, i, str(v), ha='center', va='center', color='black')

    plt.tight_layout()
    plt.show()
else:
    print("No stable segments found for confusion matrix.")
# Out:
# Stable-gear accuracy (n=2): 0.8646
#
# Classification report on stable segments:
#               precision    recall  f1-score   support
#
#            0       0.86      0.93      0.89      1429
#            1       0.89      0.99      0.94      1548
#            2       0.98      0.83      0.90      6395
#            3       0.29      0.69      0.41       498
#
#     accuracy                           0.86      9870
#    macro avg       0.76      0.86      0.79      9870
# weighted avg       0.92      0.86      0.88      9870
