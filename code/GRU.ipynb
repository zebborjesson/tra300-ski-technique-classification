# %% [markdown]
# Import libraries

# %%
import os
import pandas as pd
from sklearn.preprocessing import StandardScaler, LabelEncoder
import torch, re
import torch.nn as nn
import torch.optim as optim
torch.manual_seed(42)
from sklearn.metrics import (
    accuracy_score, f1_score, classification_report, confusion_matrix, top_k_accuracy_score
)
import matplotlib
#matplotlib.use('TkAgg')  # or 'MacOSX' if on macOS
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split

# %% [markdown]
# Read data

# %%
###VALDIATION AND TRAINING DATA
TRAINING_FOLDER = "/Users/robinoscarsson/PycharmProjects/tra300-ski-technique-classification/data_sync/outputs/Training_and_validation_set"

csv_files = [f for f in os.listdir(TRAINING_FOLDER) if f.endswith('.csv')]

dataframes = {}
for file in csv_files:
    full_path = os.path.join(TRAINING_FOLDER, file)
    df = pd.read_csv(full_path)
    dataframes[file] = df

# %%
###TEST DATA
TEST_FOLDER = "/Users/robinoscarsson/PycharmProjects/tra300-ski-technique-classification/data_sync/outputs/Test_set"

csv_files = [f for f in os.listdir(TEST_FOLDER) if f.endswith('.csv')]
dataframes_test = {}
for file in csv_files:
    full_path = os.path.join(TEST_FOLDER, file)
    df = pd.read_csv(full_path)
    dataframes_test[file] = df

# %%
####
input_cols = ["speed_kmph", "power_w", "frequency_ppm", "thrust_left_ms", "thrust_right_ms", "impulse_left_ns", "impulse_right_ns", "force_meanl_n", "force_meanr_n", "f_tot_mean_n"] #ADD columns from avaialble ones if needed
output_cols = ["Gear"]

print("Loaded CSV files:")
for k in sorted(dataframes.keys()):
    print(" •", k)

# Take a sample frame to list columns
_sample_key = next(iter(dataframes))
print("\nColumns in sample file:", _sample_key)
print(list(dataframes[_sample_key].columns))

print("\nUsing inputs:", input_cols)
print("Using output:", output_cols)
# Out:
# Loaded CSV files:
#  • BIA24-15_NR_merged_with_gear.csv
#  • BIA24-15_WR_merged_with_gear.csv
#  • BIA24-16_NR_merged_with_gear.csv
#  • BIA24-16_WR_merged_with_gear.csv
#  • BIA24-17_WR_merged_with_gear.csv
#  • BIA24-18_NR_merged_with_gear.csv
#  • BIA24-18_WR_merged_with_gear.csv
#  • BIA24-19_NR_merged_with_gear.csv
#  • BIA24-19_WR_merged_with_gear.csv
#  • BIA24-20_NR_merged_with_gear.csv
#  • BIA24-20_WR_merged_with_gear.csv
#  • BIA24-3_NR_merged_with_gear.csv
#  • BIA24-3_WR_merged_with_gear.csv
#  • BIA24-4_NR_merged_with_gear.csv
#  • BIA24-4_WR_merged_with_gear.csv
#  • BIA24-5_NR_merged_with_gear.csv
#  • BIA24-5_WR_merged_with_gear.csv
#  • BIA24-7_NR_merged_with_gear.csv
#  • BIA24-7_WR_merged_with_gear.csv
#  • BIA24-9_NR_merged_with_gear.csv
#  • BIA24-9_WR_merged_with_gear.csv
#
# Columns in sample file: BIA24-17_WR_merged_with_gear.csv
# ['tt_s', 'Lap', 'Gear', 'ns1:LatitudeDegrees', 'ns1:LongitudeDegrees', 'Sport', 'speed_kmph', 'power_w', 'frequency_ppm', 'thrust_left_ms', 'thrust_right_ms', 'impulse_left_ns', 'impulse_right_ns', 'force_meanl_n', 'force_meanr_n', 'f_tot_mean_n', 'ns1:AltitudeMeters', 'ns2:Speed', 'ns2:RunCadence', 'ns2:Watts']
#
# Using inputs: ['speed_kmph', 'power_w', 'frequency_ppm', 'thrust_left_ms', 'thrust_right_ms', 'impulse_left_ns', 'impulse_right_ns', 'force_meanl_n', 'force_meanr_n', 'f_tot_mean_n']
# Using output: ['Gear']

# %%
#Split into train/test dataframes and make sure there are no NA
train_keys = [k for k in dataframes.keys()]
test_keys = [k for k in dataframes_test.keys()]

train_df_full = pd.concat([dataframes[k] for k in train_keys], ignore_index=True) # Renamed
test_df = pd.concat([dataframes_test[k] for k in test_keys], ignore_index=True) # Renamed

needed_cols = list(set(input_cols + output_cols))
train_df_full = train_df_full.dropna(subset=needed_cols).reset_index(drop=True)
test_df = test_df.dropna(subset=needed_cols).reset_index(drop=True)

# %%
# Normalize labels: "2.0H" / "2.0V" / "2.0" -> "2.0"
label_col = output_cols[0]

def normalize_label(val: object) -> str:
    s = str(val).strip()
    m = re.search(r'^-?\d+(?:\.\d+)?', s) # take leading number (int or float)
    if m:
        return f"{float(m.group(0)):.1f}" # standardize format, e.g., 2 -> "2.0"
    return s # fall back to original string

train_df_full[label_col] = train_df_full[label_col].apply(normalize_label)
test_df[label_col] = test_df[label_col].apply(normalize_label)

# %%
# Create Train/Validation SpliT
# We split the full training data into a new (smaller) training set
# and a validation set.

try:
    train_df, val_df = train_test_split(
        train_df_full,
        test_size=0.2, # 20% for validation
        random_state=42,
        stratify=train_df_full[label_col] # Keep class distribution in splits
    )
except ValueError:
    print("Warning: Could not stratify split (likely due to rare classes). Splitting without stratification.")
    train_df, val_df = train_test_split(
        train_df_full,
        test_size=0.2, # 20% for validation
        random_state=42
    )

# %%
###Encode labels and make sure they are represented everywhere

# Encode labels using ALL labels (train_full + test) to avoid unseen-label errors
label_encoder = LabelEncoder()

#Concentenate to get one long list of labels in the
all_labels = pd.concat(
    [train_df_full[label_col], test_df[label_col]], # Use train_df_full here
    ignore_index=True
)
#Makes all lables which are strings into integers (in this case it is just e.g "1.0" -> 1
label_encoder.fit(all_labels)

###NOW TURN COLUMNS IN DATAFRAMES OF LABELS INTO THIS MAPPING (I.E into integers
y_train = label_encoder.transform(train_df[label_col]) # Use new train_df
y_val = label_encoder.transform(val_df[label_col])     # Create y_val
y_test = label_encoder.transform(test_df[label_col])
num_classes = len(label_encoder.classes_)


###Sanity check to make sure or chosen test files don't contain gears that don't exist in other sets
#create python sets of classes found in all data sets
train_classes = set(np.unique(y_train))
val_classes = set(np.unique(y_val))
test_classes = set(np.unique(y_test))

#If any class is only in test creating warning
only_in_test = sorted(list(test_classes - train_classes - val_classes))
if only_in_test:
    names_only_in_test = [label_encoder.classes_[i] for i in only_in_test]
    print("⚠️ These classes exist only in TEST (not seen in train/val):", names_only_in_test)

# %%
# Prepare inputs in terms of each timestep
X_train = train_df[input_cols].values.astype(np.float32)
X_val = val_df[input_cols].values.astype(np.float32)     # Create X_val
X_test = test_df[input_cols].values.astype(np.float32)

# ---- Convert to PyTorch tensors ----
X_train_t = torch.tensor(X_train, dtype=torch.float32)
X_val_t = torch.tensor(X_val, dtype=torch.float32)   # Create X_val_t
X_test_t = torch.tensor(X_test, dtype=torch.float32)

y_train_t = torch.tensor(y_train, dtype=torch.long)
y_val_t = torch.tensor(y_val, dtype=torch.long)     # Create y_val_t
y_test_t = torch.tensor(y_test, dtype=torch.long)

print(X_train_t.shape)
# Out:
# torch.Size([19611, 10])

# %%
###MAKE TENSOR DATA INTO SEQUENCES FOR RNN (IGNORE FOR NON SEQUENTIAL ARCHITECTURES)

SEQ_LEN = 10    # length of each sequence in seconds (samples)
STRIDE = 2      # how much to slide the window forward

def make_sequences(X_t, y_t, seq_len=SEQ_LEN, stride=STRIDE):
    """
    #Turn flat sensor data (N x features) into overlapping sequences for RNNs.
    """
    X_seq, y_seq = [], []
    for i in range(0, len(X_t) - seq_len + 1, stride):
        X_seq.append(X_t[i:i+seq_len])
        y_seq.append(y_t[i+seq_len-1])
    X_seq = torch.stack(X_seq)      # shape: (num_sequences, seq_len, num_features)
    y_seq = torch.stack(y_seq)      # shape: (num_sequences,)
    return X_seq, y_seq

# Apply to train, val, and test
X_train_seq, y_train_seq = make_sequences(X_train_t, y_train_t)
X_val_seq, y_val_seq     = make_sequences(X_val_t, y_val_t)
X_test_seq, y_test_seq   = make_sequences(X_test_t, y_test_t)

print(f"X_train_seq shape: {X_train_seq.shape}")
print(f"X_val_seq shape:   {X_val_seq.shape}")
print(f"X_test_seq shape:  {X_test_seq.shape}")
# Out:
# X_train_seq shape: torch.Size([9801, 10, 10])
# X_val_seq shape:   torch.Size([2447, 10, 10])
# X_test_seq shape:  torch.Size([2337, 10, 10])

# %%
#### WEIGHT Class weights (based on new, smaller training set)

input_dim = X_train_t.shape[1]
output_dim = num_classes

counts_np = np.bincount(y_train_seq, minlength=num_classes)
class_counts = torch.tensor(counts_np, dtype=torch.float32)
with torch.no_grad():
    class_weights = torch.where(class_counts > 0, 1.0 / class_counts, torch.tensor(0.0))
    nz = class_weights > 0
    if nz.any():
        class_weights[nz] = class_weights[nz] * (nz.sum() / class_weights[nz].sum())

print(f"The amount of inputs: Train size: {len(X_train_seq)} | Val size: {len(X_val_seq)} | Test size: {len(X_test_seq)}")
print(f"Input dim: {input_dim} | Classes: {num_classes}")
print("Label mapping (int -> original):")
for i, name in enumerate(label_encoder.classes_):
    print(f"  {i} -> {name}")
print("Training Class counts (amount of gears):", counts_np.tolist())
print(f"the weights are {class_weights}")
# Out:
# The amount of inputs: Train size: 9801 | Val size: 2447 | Test size: 2337
# Input dim: 10 | Classes: 4
# Label mapping (int -> original):
#   0 -> 0.0
#   1 -> 2.0
#   2 -> 3.0
#   3 -> 4.0
# Training Class counts (amount of gears): [1840, 1419, 5162, 1380]
# the weights are tensor([1.0034, 1.3011, 0.3577, 1.3379])

# %%
###HELPER FUNCTIONS

def plot_training(epochs, train_losses, val_losses):
    """Plot the training and validation losses."""
    plt.plot(range(epochs), train_losses, label="Training Loss")
    plt.plot(range(epochs), val_losses, "--", label="Validation Loss")
    plt.xlabel("Epoch"), plt.xlim([0, epochs - 1])
    plt.ylabel("Loss")
    plt.legend()
    plt.show()

def batches(X, y, batch_size, shuffle=True):
    n = len(X)
    idx = np.arange(n)

    #We don't want to shuffle for validation and training
    if shuffle:
        np.random.shuffle(idx)
    for start in range(0, n, batch_size):
        end = start + batch_size
        sel = idx[start:end]
        yield X[sel], y[sel]

# Source - https://stackoverflow.com/a
# Posted by isle_of_gods, modified by community. See post 'Timeline' for change history
# Retrieved 2025-11-12, License - CC BY-SA 4.0
class EarlyStopper:
    def __init__(self, patience=5, min_delta= 1e-3):
        self.patience = patience
        self.min_delta = min_delta
        self.counter = 0
        self.min_validation_loss = float('inf')

    def early_stop(self, validation_loss):
        if validation_loss < self.min_validation_loss:
            self.min_validation_loss = validation_loss
            self.counter = 0
        elif validation_loss > (self.min_validation_loss + self.min_delta):
            self.counter += 1
            if self.counter >= self.patience:
                return True
        return False

# %% [markdown]
# GRU architecture

# %%
####ARCHITECTURE
EPOCHS = 100
BATCH_SIZE = 128
PRINT_EVERY = 1
hidden_size = 16

model = nn.GRU(input_size=input_dim, hidden_size=hidden_size, num_layers=3, batch_first=True, dropout=0.2)
fc = nn.Linear(hidden_size, output_dim)  # Map hidden state → class logits
criterion = nn.CrossEntropyLoss(weight=class_weights)
optimizer = optim.Adam(model.parameters(), lr=1e-3, weight_decay=1e-5)

# %%
### Training loop
history = {'train_loss': [], 'val_loss': [], 'val_acc': []}

print("Starting training...")
early_stopper = EarlyStopper(patience=5, min_delta=0.01)
#in case early stopping
epoch_counter = 1

for epoch in range(1, EPOCHS + 1):
    # --- Training Phase ---
    model.train()
    fc.train()
    running_loss = 0.0
    for Xb, yb in batches(X_train_seq, y_train_seq, BATCH_SIZE):
        optimizer.zero_grad()

        out, h_n = model(Xb)
        out = out[:, -1,:]
        out = fc(out)

        loss = criterion(out, yb)
        loss.backward()

        optimizer.step()
        running_loss += loss.item() * Xb.size(0)

    avg_train_loss = running_loss / len(X_train_seq)
    history['train_loss'].append(avg_train_loss)

    # --- Validation Phase ---
    model.eval()
    fc.eval()

    val_loss = 0.0
    val_correct = 0
    total_samples = 0

    with torch.no_grad():
        for Xb, yb in batches(X_val_seq, y_val_seq, BATCH_SIZE, shuffle=False):
            out, _ = model(Xb)
            out = out[:, -1, :]
            out = fc(out)

            loss = criterion(out, yb)
            val_loss += loss.item() * Xb.size(0)   # weight by batch size

            preds = out.argmax(dim=1)
            val_correct += (preds == yb).sum().item()
            total_samples += Xb.size(0)
    avg_val_loss = val_loss / total_samples
    val_accuracy = val_correct / total_samples
    history['val_loss'].append(avg_val_loss)
    history['val_acc'].append(val_accuracy)

    # --- Print Epoch Stats ---
    if epoch % PRINT_EVERY == 0:
        print(f"Epoch {epoch:03d} | Train loss: {avg_train_loss:.4f} | Val loss: {avg_val_loss:.4f} | Val Acc: {val_accuracy:.4f}")

    if early_stopper.early_stop(avg_val_loss):
        print("Early stopping")
        break

    epoch_counter += 1

if epoch_counter<EPOCHS:
    plot_training(epoch_counter, history['train_loss'], history['val_loss'])
else:
    plot_training(EPOCHS, history['train_loss'], history['val_loss'])

    # --- (Removed "Save Best Model" block) ---

print("Training finished.")

# --- (Removed "Load Best Model" block) ---
print("\nUsing model state from final epoch for evaluation.")
# Out:
# Starting training...
# Epoch 001 | Train loss: 1.3658 | Val loss: 1.3169 | Val Acc: 0.3862
# Epoch 002 | Train loss: 1.1914 | Val loss: 1.0892 | Val Acc: 0.4708
# Epoch 003 | Train loss: 1.0643 | Val loss: 1.0291 | Val Acc: 0.4753
# Epoch 004 | Train loss: 1.0240 | Val loss: 0.9831 | Val Acc: 0.5783
# Epoch 005 | Train loss: 0.9915 | Val loss: 0.9544 | Val Acc: 0.6052
# Epoch 006 | Train loss: 0.9722 | Val loss: 0.9346 | Val Acc: 0.6342
# Epoch 007 | Train loss: 0.9581 | Val loss: 0.9213 | Val Acc: 0.6412
# Epoch 008 | Train loss: 0.9497 | Val loss: 0.9125 | Val Acc: 0.6310
# Epoch 009 | Train loss: 0.9425 | Val loss: 0.9048 | Val Acc: 0.6383
# Epoch 010 | Train loss: 0.9287 | Val loss: 0.8964 | Val Acc: 0.6485
# Epoch 011 | Train loss: 0.9277 | Val loss: 0.8922 | Val Acc: 0.6375
# Epoch 012 | Train loss: 0.9207 | Val loss: 0.8848 | Val Acc: 0.6412
# Epoch 013 | Train loss: 0.9207 | Val loss: 0.8794 | Val Acc: 0.6453
# Epoch 014 | Train loss: 0.9106 | Val loss: 0.8779 | Val Acc: 0.6477
# Epoch 015 | Train loss: 0.9058 | Val loss: 0.8744 | Val Acc: 0.6502
# Epoch 016 | Train loss: 0.9075 | Val loss: 0.8721 | Val Acc: 0.6510
# Epoch 017 | Train loss: 0.9052 | Val loss: 0.8708 | Val Acc: 0.6481
# Epoch 018 | Train loss: 0.9027 | Val loss: 0.8667 | Val Acc: 0.6494
# Epoch 019 | Train loss: 0.9009 | Val loss: 0.8658 | Val Acc: 0.6600
# Epoch 020 | Train loss: 0.8948 | Val loss: 0.8639 | Val Acc: 0.6579
# Epoch 021 | Train loss: 0.8998 | Val loss: 0.8637 | Val Acc: 0.6539
# Epoch 022 | Train loss: 0.8931 | Val loss: 0.8617 | Val Acc: 0.6678
# Epoch 023 | Train loss: 0.8937 | Val loss: 0.8592 | Val Acc: 0.6620
# Epoch 024 | Train loss: 0.8875 | Val loss: 0.8581 | Val Acc: 0.6637
# Epoch 025 | Train loss: 0.8928 | Val loss: 0.8601 | Val Acc: 0.6535
# Epoch 026 | Train loss: 0.8860 | Val loss: 0.8593 | Val Acc: 0.6678
# Epoch 027 | Train loss: 0.8827 | Val loss: 0.8580 | Val Acc: 0.6657
# Epoch 028 | Train loss: 0.8828 | Val loss: 0.8573 | Val Acc: 0.6682
# Epoch 029 | Train loss: 0.8812 | Val loss: 0.8552 | Val Acc: 0.6706
# Epoch 030 | Train loss: 0.8876 | Val loss: 0.8550 | Val Acc: 0.6571
# Epoch 031 | Train loss: 0.8809 | Val loss: 0.8541 | Val Acc: 0.6633
# Epoch 032 | Train loss: 0.8851 | Val loss: 0.8556 | Val Acc: 0.6739
# Epoch 033 | Train loss: 0.8808 | Val loss: 0.8566 | Val Acc: 0.6612
# Epoch 034 | Train loss: 0.8805 | Val loss: 0.8546 | Val Acc: 0.6686
# Epoch 035 | Train loss: 0.8799 | Val loss: 0.8570 | Val Acc: 0.6686
# Epoch 036 | Train loss: 0.8771 | Val loss: 0.8528 | Val Acc: 0.6653
# Epoch 037 | Train loss: 0.8758 | Val loss: 0.8534 | Val Acc: 0.6710
# Epoch 038 | Train loss: 0.8754 | Val loss: 0.8522 | Val Acc: 0.6649
# Epoch 039 | Train loss: 0.8740 | Val loss: 0.8537 | Val Acc: 0.6657
# Epoch 040 | Train loss: 0.8725 | Val loss: 0.8523 | Val Acc: 0.6653
# Epoch 041 | Train loss: 0.8743 | Val loss: 0.8534 | Val Acc: 0.6633
# Epoch 042 | Train loss: 0.8728 | Val loss: 0.8507 | Val Acc: 0.6727
# Epoch 043 | Train loss: 0.8698 | Val loss: 0.8511 | Val Acc: 0.6776
# Epoch 044 | Train loss: 0.8670 | Val loss: 0.8515 | Val Acc: 0.6584
# Epoch 045 | Train loss: 0.8698 | Val loss: 0.8532 | Val Acc: 0.6629
# Epoch 046 | Train loss: 0.8717 | Val loss: 0.8498 | Val Acc: 0.6694
# Epoch 047 | Train loss: 0.8734 | Val loss: 0.8493 | Val Acc: 0.6678
# Epoch 048 | Train loss: 0.8708 | Val loss: 0.8498 | Val Acc: 0.6751
# Epoch 049 | Train loss: 0.8675 | Val loss: 0.8504 | Val Acc: 0.6665
# Epoch 050 | Train loss: 0.8695 | Val loss: 0.8492 | Val Acc: 0.6686
# Epoch 051 | Train loss: 0.8672 | Val loss: 0.8504 | Val Acc: 0.6743
# Epoch 052 | Train loss: 0.8677 | Val loss: 0.8494 | Val Acc: 0.6661
# Epoch 053 | Train loss: 0.8649 | Val loss: 0.8495 | Val Acc: 0.6706
# Epoch 054 | Train loss: 0.8643 | Val loss: 0.8532 | Val Acc: 0.6604
# Epoch 055 | Train loss: 0.8666 | Val loss: 0.8511 | Val Acc: 0.6588
# Epoch 056 | Train loss: 0.8663 | Val loss: 0.8486 | Val Acc: 0.6731
# Epoch 057 | Train loss: 0.8655 | Val loss: 0.8515 | Val Acc: 0.6653
# Epoch 058 | Train loss: 0.8639 | Val loss: 0.8467 | Val Acc: 0.6727
# Epoch 059 | Train loss: 0.8654 | Val loss: 0.8478 | Val Acc: 0.6673
# Epoch 060 | Train loss: 0.8614 | Val loss: 0.8475 | Val Acc: 0.6612
# Epoch 061 | Train loss: 0.8629 | Val loss: 0.8506 | Val Acc: 0.6649
# Epoch 062 | Train loss: 0.8592 | Val loss: 0.8466 | Val Acc: 0.6641
# Epoch 063 | Train loss: 0.8601 | Val loss: 0.8482 | Val Acc: 0.6718
# Epoch 064 | Train loss: 0.8547 | Val loss: 0.8512 | Val Acc: 0.6661
# Epoch 065 | Train loss: 0.8600 | Val loss: 0.8491 | Val Acc: 0.6649
# Epoch 066 | Train loss: 0.8546 | Val loss: 0.8487 | Val Acc: 0.6706
# Epoch 067 | Train loss: 0.8595 | Val loss: 0.8505 | Val Acc: 0.6649
# Epoch 068 | Train loss: 0.8589 | Val loss: 0.8480 | Val Acc: 0.6678
# Epoch 069 | Train loss: 0.8576 | Val loss: 0.8533 | Val Acc: 0.6645
# Epoch 070 | Train loss: 0.8573 | Val loss: 0.8488 | Val Acc: 0.6723
# Epoch 071 | Train loss: 0.8568 | Val loss: 0.8509 | Val Acc: 0.6575
# Epoch 072 | Train loss: 0.8596 | Val loss: 0.8515 | Val Acc: 0.6694
# Epoch 073 | Train loss: 0.8597 | Val loss: 0.8521 | Val Acc: 0.6633
# Epoch 074 | Train loss: 0.8593 | Val loss: 0.8525 | Val Acc: 0.6657
# Epoch 075 | Train loss: 0.8567 | Val loss: 0.8528 | Val Acc: 0.6620
# Epoch 076 | Train loss: 0.8524 | Val loss: 0.8511 | Val Acc: 0.6641
# Epoch 077 | Train loss: 0.8543 | Val loss: 0.8529 | Val Acc: 0.6608
# Epoch 078 | Train loss: 0.8546 | Val loss: 0.8509 | Val Acc: 0.6678
# Epoch 079 | Train loss: 0.8504 | Val loss: 0.8543 | Val Acc: 0.6633
# Epoch 080 | Train loss: 0.8544 | Val loss: 0.8496 | Val Acc: 0.6682
# Epoch 081 | Train loss: 0.8529 | Val loss: 0.8519 | Val Acc: 0.6673
# Epoch 082 | Train loss: 0.8482 | Val loss: 0.8530 | Val Acc: 0.6673
# Epoch 083 | Train loss: 0.8476 | Val loss: 0.8506 | Val Acc: 0.6661
# Epoch 084 | Train loss: 0.8567 | Val loss: 0.8534 | Val Acc: 0.6665
# Epoch 085 | Train loss: 0.8506 | Val loss: 0.8544 | Val Acc: 0.6661
# Epoch 086 | Train loss: 0.8516 | Val loss: 0.8504 | Val Acc: 0.6665
# Epoch 087 | Train loss: 0.8496 | Val loss: 0.8522 | Val Acc: 0.6665
# Epoch 088 | Train loss: 0.8534 | Val loss: 0.8549 | Val Acc: 0.6682
# Epoch 089 | Train loss: 0.8459 | Val loss: 0.8528 | Val Acc: 0.6620
# Epoch 090 | Train loss: 0.8495 | Val loss: 0.8531 | Val Acc: 0.6575
# Epoch 091 | Train loss: 0.8501 | Val loss: 0.8540 | Val Acc: 0.6633
# Epoch 092 | Train loss: 0.8440 | Val loss: 0.8516 | Val Acc: 0.6690
# Epoch 093 | Train loss: 0.8492 | Val loss: 0.8537 | Val Acc: 0.6624
# Epoch 094 | Train loss: 0.8487 | Val loss: 0.8540 | Val Acc: 0.6698
# Epoch 095 | Train loss: 0.8482 | Val loss: 0.8572 | Val Acc: 0.6616
# Epoch 096 | Train loss: 0.8423 | Val loss: 0.8552 | Val Acc: 0.6588
# Epoch 097 | Train loss: 0.8455 | Val loss: 0.8555 | Val Acc: 0.6641
# Epoch 098 | Train loss: 0.8466 | Val loss: 0.8555 | Val Acc: 0.6673
# Epoch 099 | Train loss: 0.8408 | Val loss: 0.8559 | Val Acc: 0.6657
# Epoch 100 | Train loss: 0.8458 | Val loss: 0.8564 | Val Acc: 0.6690
# Training finished.
#
# Using model state from final epoch for evaluation.

# %%
model.eval()
fc.eval()

all_preds = []
all_true = []

with torch.no_grad():
    for Xb, yb in batches(X_test_seq, y_test_seq, BATCH_SIZE, shuffle=False):
        out, _ = model(Xb)          # (batch, seq_len, hidden)
        out = out[:, -1, :]       # take last timestep
        logits = fc(out)          # (batch, num_classes)
        preds = logits.argmax(dim=1)

        all_preds.append(preds.cpu())
        all_true.append(yb.cpu())
# Concatenate all batches
y_pred = torch.cat(all_preds).numpy()
y_true = torch.cat(all_true).numpy()

# Compute accuracy
acc = accuracy_score(y_true, y_pred)
print(f"Test Accuracy: {acc:.4f}")

# Confusion matrix
target_names = list(label_encoder.classes_)
cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(6, 5))
plt.imshow(cm, interpolation='nearest', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.xticks(ticks=np.arange(len(target_names)), labels=target_names, rotation=45, ha='right')
plt.yticks(ticks=np.arange(len(target_names)), labels=target_names)

# Annotate each cell
for (i, j), v in np.ndenumerate(cm):
    plt.text(j, i, str(v), ha='center', va='center', color='black')

plt.tight_layout()
plt.show()
# Out:
# Test Accuracy: 0.6812
