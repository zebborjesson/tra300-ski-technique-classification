# %% [markdown]
# Import libraries

# %%
import os
import pandas as pd
from sklearn.preprocessing import StandardScaler, LabelEncoder
import torch, re
import torch.nn as nn
import torch.optim as optim
torch.manual_seed(42)
from sklearn.metrics import (
    accuracy_score, f1_score, classification_report, confusion_matrix, top_k_accuracy_score
)
import matplotlib
#matplotlib.use('TkAgg')  # or 'MacOSX' if on macOS
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split

# %% [markdown]
# Read data

# %%
###VALDIATION AND TRAINING DATA
TRAINING_FOLDER = "/Users/robinoscarsson/PycharmProjects/tra300-ski-technique-classification/datasets/NR_split_on_skiers/train_val"

csv_files = [f for f in os.listdir(TRAINING_FOLDER) if f.endswith('.csv')]

dataframes = {}
for file in csv_files:
    full_path = os.path.join(TRAINING_FOLDER, file)
    df = pd.read_csv(full_path)
    dataframes[file] = df

# %%
###TEST DATA
TEST_FOLDER = "/Users/robinoscarsson/PycharmProjects/tra300-ski-technique-classification/datasets/NR_split_on_skiers/test"

csv_files = [f for f in os.listdir(TEST_FOLDER) if f.endswith('.csv')]
dataframes_test = {}
for file in csv_files:
    full_path = os.path.join(TEST_FOLDER, file)
    df = pd.read_csv(full_path)
    dataframes_test[file] = df

print(f"test data files {dataframes_test.keys()}")
# Out:
# test data files dict_keys(['BIA24-22_NR_merged_with_gear.csv', 'BIA24-5_NR_merged_with_gear.csv'])

# %%
####
input_cols_poles =  ['speed_kmph', 'power_w', 'frequency_ppm', 'thrust_left_ms', 'thrust_right_ms', 'impulse_left_ns', 'impulse_right_ns', 'force_meanl_n', 'force_meanr_n', 'f_tot_mean_n'] #ADD columns from avaialble ones if needed
GNNS_poles =  ['ns1:AltitudeMeters', 'ns2:Speed', 'ns2:RunCadence', 'ns2:Watts']
output_cols = ["Gear"]
input_cols = input_cols_poles + GNNS_poles

print("Loaded CSV files:")
for k in sorted(dataframes.keys()):
    print(" •", k)

# Take a sample frame to list columns
_sample_key = next(iter(dataframes))
print("\nColumns in sample file:", _sample_key)
print(list(dataframes[_sample_key].columns))

print("\nUsing inputs:", input_cols)
print("Using output:", output_cols)
# Out:
# Loaded CSV files:
#  • BIA24-15_NR_merged_with_gear.csv
#  • BIA24-16_NR_merged_with_gear.csv
#  • BIA24-18_NR_merged_with_gear.csv
#  • BIA24-19_NR_merged_with_gear.csv
#  • BIA24-20_NR_merged_with_gear.csv
#  • BIA24-3_NR_merged_with_gear.csv
#  • BIA24-4_NR_merged_with_gear.csv
#  • BIA24-7_NR_merged_with_gear.csv
#  • BIA24-8_NR_merged_with_gear.csv
#  • BIA24-9_NR_merged_with_gear.csv
#
# Columns in sample file: BIA24-8_NR_merged_with_gear.csv
# ['tt_s', 'Lap', 'Gear', 'ns1:LatitudeDegrees', 'ns1:LongitudeDegrees', 'Sport', 'Variant', 'speed_kmph', 'power_w', 'frequency_ppm', 'thrust_left_ms', 'thrust_right_ms', 'impulse_left_ns', 'impulse_right_ns', 'force_meanl_n', 'force_meanr_n', 'f_tot_mean_n', 'ns1:AltitudeMeters', 'ns2:Speed', 'ns2:RunCadence', 'ns2:Watts']
#
# Using inputs: ['speed_kmph', 'power_w', 'frequency_ppm', 'thrust_left_ms', 'thrust_right_ms', 'impulse_left_ns', 'impulse_right_ns', 'force_meanl_n', 'force_meanr_n', 'f_tot_mean_n', 'ns1:AltitudeMeters', 'ns2:Speed', 'ns2:RunCadence', 'ns2:Watts']
# Using output: ['Gear']

# %%
#Split into train/test dataframes and make sure there are no NA
train_keys = [k for k in dataframes.keys()]
test_keys = [k for k in dataframes_test.keys()]

train_df_full = pd.concat([dataframes[k] for k in train_keys], ignore_index=True) # Renamed
test_df = pd.concat([dataframes_test[k] for k in test_keys], ignore_index=True) # Renamed

needed_cols = list(set(input_cols + output_cols))
train_df_full = train_df_full.dropna(subset=needed_cols).reset_index(drop=True)
test_df = test_df.dropna(subset=needed_cols).reset_index(drop=True)

print(len(test_df))
# Out:
# 2419

# %%
# Normalize labels: "2.0H" / "2.0V" / "2.0" -> "2.0"
label_col = output_cols[0]

def normalize_label(val: object) -> str:
    s = str(val).strip()
    m = re.search(r'^-?\d+(?:\.\d+)?', s) # take leading number (int or float)
    if m:
        return f"{float(m.group(0)):.1f}" # standardize format, e.g., 2 -> "2.0"
    return s # fall back to original string

train_df_full[label_col] = train_df_full[label_col].apply(normalize_label)
test_df[label_col] = test_df[label_col].apply(normalize_label)

# %%
# Create Train/Validation SpliT
# We split the full training data into a new (smaller) training set
# and a validation set.

try:
    train_df, val_df = train_test_split(
        train_df_full,
        test_size=0.2, # 20% for validation
        random_state=42,
        stratify=train_df_full[label_col] # Keep class distribution in splits
    )
except ValueError:
    print("Warning: Could not stratify split (likely due to rare classes). Splitting without stratification.")
    train_df, val_df = train_test_split(
        train_df_full,
        test_size=0.2, # 20% for validation
        random_state=42
    )

# %%
###Encode labels and make sure they are represented everywhere

# Encode labels using ALL labels (train_full + test) to avoid unseen-label errors
label_encoder = LabelEncoder()

#Concentenate to get one long list of labels in the
all_labels = pd.concat(
    [train_df_full[label_col], test_df[label_col]], # Use train_df_full here
    ignore_index=True
)

#Makes all lables which are strings into integers (in this case it is just e.g "1.0" -> 1
label_encoder.fit(all_labels)

###NOW TURN COLUMNS IN DATAFRAMES OF LABELS INTO THIS MAPPING (I.E into integers
y_train = label_encoder.transform(train_df[label_col]) # Use new train_df
y_val = label_encoder.transform(val_df[label_col])     # Create y_val
y_test = label_encoder.transform(test_df[label_col])
num_classes = len(label_encoder.classes_)

###Sanity check to make sure or chosen test files don't contain gears that don't exist in other sets
#create python sets of classes found in all data sets
train_classes = set(np.unique(y_train))
val_classes = set(np.unique(y_val))
test_classes = set(np.unique(y_test))

#If any class is only in test creating warning
only_in_test = sorted(list(test_classes - train_classes - val_classes))
if only_in_test:
    names_only_in_test = [label_encoder.classes_[i] for i in only_in_test]
    print("⚠️ These classes exist only in TEST (not seen in train/val):", names_only_in_test)

# %%
# Prepare inputs in terms of each timestep
X_train = train_df[input_cols].values.astype(np.float32)
X_val = val_df[input_cols].values.astype(np.float32)     # Create X_val
X_test = test_df[input_cols].values.astype(np.float32)

# ---- Convert to PyTorch tensors ----
X_train_t = torch.tensor(X_train, dtype=torch.float32)
X_val_t = torch.tensor(X_val, dtype=torch.float32)   # Create X_val_t
X_test_t = torch.tensor(X_test, dtype=torch.float32)

y_train_t = torch.tensor(y_train, dtype=torch.long)
y_val_t = torch.tensor(y_val, dtype=torch.long)     # Create y_val_t
y_test_t = torch.tensor(y_test, dtype=torch.long)

print(X_test_t.shape)
print(y_test_t.shape)
# Out:
# torch.Size([2419, 14])
# torch.Size([2419])

# %%
###MAKE TENSOR DATA INTO SEQUENCES FOR RNN (IGNORE FOR NON SEQUENTIAL ARCHITECTURES)

SEQ_LEN = 10    # length of each sequence in seconds (samples)
STRIDE = 2      # how much to slide the window forward

def make_sequences(X_t, y_t, seq_len=SEQ_LEN, stride=STRIDE):
    """
    #Turn flat sensor data (N x features) into overlapping sequences for RNNs.
    """
    X_seq, y_seq = [], []
    for i in range(0, len(X_t) - seq_len + 1, stride):
        X_seq.append(X_t[i:i+seq_len])
        y_seq.append(y_t[i:i+seq_len])
    X_seq = torch.stack(X_seq)      # shape: (num_sequences, seq_len, num_features)
    y_seq = torch.stack(y_seq)      # shape: (num_sequences,)
    return X_seq, y_seq

# Apply to train, val, and test
X_train_seq, y_train_seq = make_sequences(X_train_t, y_train_t)
X_val_seq, y_val_seq     = make_sequences(X_val_t, y_val_t)
X_test_seq, y_test_seq   = make_sequences(X_test_t, y_test_t, seq_len=SEQ_LEN, stride=SEQ_LEN)

print(y_test_seq.shape)
print(f"X_train_seq shape: {X_train_seq.shape}")
print(f"X_val_seq shape:   {X_val_seq.shape}")
print(f"X_test_seq shape:  {X_test_seq.shape}")

print(f"y_train_seq shape: {y_train_seq.shape}")
# Out:
# torch.Size([241, 10])
# X_train_seq shape: torch.Size([4504, 10, 14])
# X_val_seq shape:   torch.Size([1123, 10, 14])
# X_test_seq shape:  torch.Size([241, 10, 14])
# y_train_seq shape: torch.Size([4504, 10])

# %%
#### WEIGHT Class weights (based on new, smaller training set)

input_dim = X_train_seq.shape[2]
output_dim = num_classes
print(input_dim)
counts_np = np.bincount(y_train_seq.reshape(-1) , minlength=num_classes)
class_counts = torch.tensor(counts_np, dtype=torch.float32)
with torch.no_grad():
    class_weights = torch.where(class_counts > 0, 1.0 / class_counts, torch.tensor(0.0))
    nz = class_weights > 0
    if nz.any():
        class_weights[nz] = class_weights[nz] * (nz.sum() / class_weights[nz].sum())

print(f"The amount of inputs: Train size: {len(X_train_seq)} | Val size: {len(X_val_seq)} | Test size: {len(X_test_seq)}")
print(f"Input dim: {input_dim} | Classes: {num_classes}")
print("Label mapping (int -> original):")
for i, name in enumerate(label_encoder.classes_):
    print(f"  {i} -> {name}")
print("Training Class counts (amount of gears):", counts_np.tolist())
print(f"the weights are {class_weights}")
# Out:
# 14
# The amount of inputs: Train size: 4504 | Val size: 1123 | Test size: 241
# Input dim: 14 | Classes: 4
# Label mapping (int -> original):
#   0 -> 0.0
#   1 -> 2.0
#   2 -> 3.0
#   3 -> 4.0
# Training Class counts (amount of gears): [8981, 6700, 23462, 5897]
# the weights are tensor([0.9420, 1.2627, 0.3606, 1.4347])

# %%
###HELPER FUNCTIONS

def _stable_indices(y, n=2):
    """Return positional indices where the label has been stable for n before and n after."""
    y = y.reset_index(drop=True)
    idx = []
    for i in range(n, len(y) - n):
        c = y.iloc[i]
        # use iloc for positional comparisons
        if all(y.iloc[i - j] == c and y.iloc[i + j] == c for j in range(1, n + 1)):
            idx.append(i)
    return idx

def accuracy_when_stable_gear(y, pred, n=2):
    """Accuracy only on timesteps where the gear is stable for n steps before & after."""
    y = y.reset_index(drop=True)
    pred = np.asarray(pred)
    idx = _stable_indices(y, n)
    if len(idx) == 0:
        return np.nan
    return np.mean(y.iloc[idx].values == pred[idx])

def classification_report_when_stable_gear(y, pred, n=2):
    """Sklearn classification_report restricted to stable gear timesteps."""
    y = y.reset_index(drop=True)
    pred = np.asarray(pred)
    idx = _stable_indices(y, n)
    if len(idx) == 0:
        return "No stable segments found."
    return classification_report(y.iloc[idx], pred[idx], labels=ALL_LABELS, zero_division=0)

def confusion_matrix_when_stable_gear(y, pred, n=2):
    """Confusion matrix restricted to stable gear timesteps."""
    y = y.reset_index(drop=True)
    pred = np.asarray(pred)
    idx = _stable_indices(y, n)
    if len(idx) == 0:
        return None
    return confusion_matrix(y.iloc[idx], pred[idx], labels=ALL_LABELS)


def plot_training(epochs, train_losses, val_losses):
    """Plot the training and validation losses."""
    plt.plot(range(epochs), train_losses, label="Training Loss")
    plt.plot(range(epochs), val_losses, "--", label="Validation Loss")
    plt.xlabel("Epoch"), plt.xlim([0, epochs - 1])
    plt.ylabel("Loss")
    plt.legend()
    plt.show()


def plot_training(epochs, train_losses, val_losses):
    """Plot the training and validation losses."""
    plt.plot(range(epochs), train_losses, label="Training Loss")
    plt.plot(range(epochs), val_losses, "--", label="Validation Loss")
    plt.xlabel("Epoch"), plt.xlim([0, epochs - 1])
    plt.ylabel("Loss")
    plt.legend()
    plt.show()

def batches(X, y, batch_size, shuffle=True):
    n = len(X)
    idx = np.arange(n)

    #We don't want to shuffle for validation and training
    if shuffle:
        np.random.shuffle(idx)
    for start in range(0, n, batch_size):
        end = start + batch_size
        sel = idx[start:end]
        yield X[sel], y[sel]

# Source - https://stackoverflow.com/a
# Posted by isle_of_gods, modified by community. See post 'Timeline' for change history
# Retrieved 2025-11-12, License - CC BY-SA 4.0
class EarlyStopper:
    def __init__(self, patience=5, min_delta= 1e-3):
        self.patience = patience
        self.min_delta = min_delta
        self.counter = 0
        self.min_validation_loss = float('inf')

    def early_stop(self, validation_loss):
        if validation_loss < self.min_validation_loss:
            self.min_validation_loss = validation_loss
            self.counter = 0
        elif validation_loss > (self.min_validation_loss + self.min_delta):
            self.counter += 1
            if self.counter >= self.patience:
                return True
        return False

# %% [markdown]
# GRU architecture

# %%
####ARCHITECTURE
EPOCHS = 150
BATCH_SIZE = 128
PRINT_EVERY = 1
hidden_size = 64

model = nn.GRU(input_size=input_dim, hidden_size=hidden_size, num_layers=3, batch_first=True, dropout=0.2)
fc = nn.Linear(hidden_size, output_dim)  # Map hidden state → class logits
criterion = nn.CrossEntropyLoss(weight=class_weights)
optimizer = optim.Adam(list(model.parameters())+list(fc.parameters()), lr=1e-4, weight_decay=1e-5)

# %%
### Training loop
history = {'train_loss': [], 'val_loss': [], 'val_acc': []}

print("Starting training...")
early_stopper = EarlyStopper(patience=5, min_delta=0.1)
#in case early stopping
epoch_counter = 1

for epoch in range(1, EPOCHS + 1):
    # --- Training Phase ---
    model.train()
    fc.train()

    running_loss = 0.0
    total_train_samples = 0

    for Xb, yb in batches(X_train_seq, y_train_seq, BATCH_SIZE):
        optimizer.zero_grad()

        # Forward pass
        out, _ = model(Xb)          # out: (batch, seq_len, hidden)
        logits = fc(out)            # logits: (batch, seq_len, num_classes)

        # Flatten batch + sequence dims
        loss = criterion(
            logits.reshape(-1, output_dim),   # (batch*seq_len, C)
            yb.reshape(-1)                    # (batch*seq_len)
        )

        # Backprop
        loss.backward()
        optimizer.step()

        running_loss += loss.item() * Xb.size(0) * Xb.size(1)  # multiply by seq_len
        total_train_samples += Xb.size(0) * Xb.size(1)

    avg_train_loss = running_loss / total_train_samples
    history['train_loss'].append(avg_train_loss)

    # --- Validation Phase ---
    model.eval()
    fc.eval()

    val_loss = 0.0
    val_correct = 0
    total_val_samples = 0

    with torch.no_grad():
        for Xb, yb in batches(X_val_seq, y_val_seq, BATCH_SIZE, shuffle=False):

            out, _ = model(Xb)           # (batch, seq_len, hidden)
            logits = fc(out)             # (batch, seq_len, num_classes)

            # Loss over all timesteps
            loss = criterion(
                logits.reshape(-1, output_dim), #Gives us [batch* seq_length, num_classes]
                yb.reshape(-1)
            )

            val_loss += loss.item() * Xb.size(0) * Xb.size(1)

            # Predictions for accuracy
            preds = logits.argmax(dim=2)      # (batch, seq_len)
            val_correct += (preds == yb).sum().item()
            total_val_samples += yb.numel()

    avg_val_loss = val_loss / total_val_samples
    val_accuracy = val_correct / total_val_samples
    history['val_loss'].append(avg_val_loss)
    history['val_acc'].append(val_accuracy)

    # --- Print Epoch Stats ---
    if epoch % PRINT_EVERY == 0:
        print(f"Epoch {epoch:03d} | Train loss: {avg_train_loss:.4f} | Val loss: {avg_val_loss:.4f} | Val Acc: {val_accuracy:.4f}")

    if early_stopper.early_stop(avg_val_loss):
        print("Early stopping")
        break

    epoch_counter += 1

if epoch_counter<EPOCHS:
    plot_training(epoch_counter, history['train_loss'], history['val_loss'])
else:
    plot_training(EPOCHS, history['train_loss'], history['val_loss'])

    # --- (Removed "Save Best Model" block) ---

print("Training finished.")

# --- (Removed "Load Best Model" block) ---
print("\nUsing model state from final epoch for evaluation.")
# Out:
# Starting training...
# Epoch 001 | Train loss: 1.3843 | Val loss: 1.3798 | Val Acc: 0.2571
# Epoch 002 | Train loss: 1.3740 | Val loss: 1.3675 | Val Acc: 0.3043
# Epoch 003 | Train loss: 1.3569 | Val loss: 1.3443 | Val Acc: 0.3240
# Epoch 004 | Train loss: 1.3236 | Val loss: 1.2979 | Val Acc: 0.3389
# Epoch 005 | Train loss: 1.2571 | Val loss: 1.2031 | Val Acc: 0.3829
# Epoch 006 | Train loss: 1.1342 | Val loss: 1.0540 | Val Acc: 0.4586
# Epoch 007 | Train loss: 1.0065 | Val loss: 0.9636 | Val Acc: 0.5079
# Epoch 008 | Train loss: 0.9396 | Val loss: 0.9174 | Val Acc: 0.5330
# Epoch 009 | Train loss: 0.8997 | Val loss: 0.8839 | Val Acc: 0.5485
# Epoch 010 | Train loss: 0.8703 | Val loss: 0.8570 | Val Acc: 0.5672
# Epoch 011 | Train loss: 0.8453 | Val loss: 0.8332 | Val Acc: 0.5809
# Epoch 012 | Train loss: 0.8236 | Val loss: 0.8133 | Val Acc: 0.5955
# Epoch 013 | Train loss: 0.8055 | Val loss: 0.7968 | Val Acc: 0.6131
# Epoch 014 | Train loss: 0.7904 | Val loss: 0.7815 | Val Acc: 0.6231
# Epoch 015 | Train loss: 0.7756 | Val loss: 0.7683 | Val Acc: 0.6293
# Epoch 016 | Train loss: 0.7622 | Val loss: 0.7561 | Val Acc: 0.6460
# Epoch 017 | Train loss: 0.7523 | Val loss: 0.7442 | Val Acc: 0.6700
# Epoch 018 | Train loss: 0.7394 | Val loss: 0.7330 | Val Acc: 0.6713
# Epoch 019 | Train loss: 0.7274 | Val loss: 0.7218 | Val Acc: 0.6784
# Epoch 020 | Train loss: 0.7164 | Val loss: 0.7114 | Val Acc: 0.6824
# Epoch 021 | Train loss: 0.7057 | Val loss: 0.7015 | Val Acc: 0.6908
# Epoch 022 | Train loss: 0.6962 | Val loss: 0.6923 | Val Acc: 0.6977
# Epoch 023 | Train loss: 0.6877 | Val loss: 0.6839 | Val Acc: 0.7039
# Epoch 024 | Train loss: 0.6797 | Val loss: 0.6763 | Val Acc: 0.7011
# Epoch 025 | Train loss: 0.6725 | Val loss: 0.6678 | Val Acc: 0.7098
# Epoch 026 | Train loss: 0.6640 | Val loss: 0.6610 | Val Acc: 0.7158
# Epoch 027 | Train loss: 0.6575 | Val loss: 0.6549 | Val Acc: 0.7179
# Epoch 028 | Train loss: 0.6512 | Val loss: 0.6489 | Val Acc: 0.7177
# Epoch 029 | Train loss: 0.6453 | Val loss: 0.6428 | Val Acc: 0.7199
# Epoch 030 | Train loss: 0.6387 | Val loss: 0.6380 | Val Acc: 0.7286
# Epoch 031 | Train loss: 0.6337 | Val loss: 0.6327 | Val Acc: 0.7312
# Epoch 032 | Train loss: 0.6301 | Val loss: 0.6289 | Val Acc: 0.7248
# Epoch 033 | Train loss: 0.6252 | Val loss: 0.6244 | Val Acc: 0.7361
# Epoch 034 | Train loss: 0.6203 | Val loss: 0.6199 | Val Acc: 0.7358
# Epoch 035 | Train loss: 0.6164 | Val loss: 0.6161 | Val Acc: 0.7361
# Epoch 036 | Train loss: 0.6150 | Val loss: 0.6122 | Val Acc: 0.7391
# Epoch 037 | Train loss: 0.6094 | Val loss: 0.6092 | Val Acc: 0.7370
# Epoch 038 | Train loss: 0.6074 | Val loss: 0.6058 | Val Acc: 0.7372
# Epoch 039 | Train loss: 0.6049 | Val loss: 0.6021 | Val Acc: 0.7452
# Epoch 040 | Train loss: 0.6001 | Val loss: 0.5998 | Val Acc: 0.7415
# Epoch 041 | Train loss: 0.5968 | Val loss: 0.5971 | Val Acc: 0.7496
# Epoch 042 | Train loss: 0.5922 | Val loss: 0.5947 | Val Acc: 0.7422
# Epoch 043 | Train loss: 0.5905 | Val loss: 0.5921 | Val Acc: 0.7488
# Epoch 044 | Train loss: 0.5889 | Val loss: 0.5905 | Val Acc: 0.7487
# Epoch 045 | Train loss: 0.5848 | Val loss: 0.5876 | Val Acc: 0.7497
# Epoch 046 | Train loss: 0.5826 | Val loss: 0.5858 | Val Acc: 0.7505
# Epoch 047 | Train loss: 0.5811 | Val loss: 0.5839 | Val Acc: 0.7528
# Epoch 048 | Train loss: 0.5810 | Val loss: 0.5821 | Val Acc: 0.7519
# Epoch 049 | Train loss: 0.5764 | Val loss: 0.5804 | Val Acc: 0.7572
# Epoch 050 | Train loss: 0.5743 | Val loss: 0.5795 | Val Acc: 0.7548
# Epoch 051 | Train loss: 0.5758 | Val loss: 0.5777 | Val Acc: 0.7568
# Epoch 052 | Train loss: 0.5699 | Val loss: 0.5763 | Val Acc: 0.7537
# Epoch 053 | Train loss: 0.5694 | Val loss: 0.5741 | Val Acc: 0.7628
# Epoch 054 | Train loss: 0.5686 | Val loss: 0.5730 | Val Acc: 0.7585
# Epoch 055 | Train loss: 0.5689 | Val loss: 0.5715 | Val Acc: 0.7584
# Epoch 056 | Train loss: 0.5670 | Val loss: 0.5699 | Val Acc: 0.7609
# Epoch 057 | Train loss: 0.5641 | Val loss: 0.5704 | Val Acc: 0.7557
# Epoch 058 | Train loss: 0.5631 | Val loss: 0.5680 | Val Acc: 0.7630
# Epoch 059 | Train loss: 0.5613 | Val loss: 0.5676 | Val Acc: 0.7606
# Epoch 060 | Train loss: 0.5578 | Val loss: 0.5659 | Val Acc: 0.7646
# Epoch 061 | Train loss: 0.5574 | Val loss: 0.5647 | Val Acc: 0.7668
# Epoch 062 | Train loss: 0.5583 | Val loss: 0.5643 | Val Acc: 0.7629
# Epoch 063 | Train loss: 0.5556 | Val loss: 0.5634 | Val Acc: 0.7633
# Epoch 064 | Train loss: 0.5562 | Val loss: 0.5622 | Val Acc: 0.7646
# Epoch 065 | Train loss: 0.5522 | Val loss: 0.5605 | Val Acc: 0.7663
# Epoch 066 | Train loss: 0.5523 | Val loss: 0.5605 | Val Acc: 0.7630
# Epoch 067 | Train loss: 0.5489 | Val loss: 0.5595 | Val Acc: 0.7641
# Epoch 068 | Train loss: 0.5487 | Val loss: 0.5585 | Val Acc: 0.7651
# Epoch 069 | Train loss: 0.5472 | Val loss: 0.5588 | Val Acc: 0.7684
# Epoch 070 | Train loss: 0.5464 | Val loss: 0.5582 | Val Acc: 0.7652
# Epoch 071 | Train loss: 0.5464 | Val loss: 0.5580 | Val Acc: 0.7655
# Epoch 072 | Train loss: 0.5474 | Val loss: 0.5561 | Val Acc: 0.7664
# Epoch 073 | Train loss: 0.5436 | Val loss: 0.5564 | Val Acc: 0.7629
# Epoch 074 | Train loss: 0.5442 | Val loss: 0.5558 | Val Acc: 0.7666
# Epoch 075 | Train loss: 0.5409 | Val loss: 0.5551 | Val Acc: 0.7643
# Epoch 076 | Train loss: 0.5424 | Val loss: 0.5540 | Val Acc: 0.7645
# Epoch 077 | Train loss: 0.5407 | Val loss: 0.5540 | Val Acc: 0.7655
# Epoch 078 | Train loss: 0.5403 | Val loss: 0.5519 | Val Acc: 0.7676
# Epoch 079 | Train loss: 0.5402 | Val loss: 0.5515 | Val Acc: 0.7698
# Epoch 080 | Train loss: 0.5378 | Val loss: 0.5518 | Val Acc: 0.7651
# Epoch 081 | Train loss: 0.5378 | Val loss: 0.5510 | Val Acc: 0.7693
# Epoch 082 | Train loss: 0.5342 | Val loss: 0.5509 | Val Acc: 0.7682
# Epoch 083 | Train loss: 0.5366 | Val loss: 0.5498 | Val Acc: 0.7686
# Epoch 084 | Train loss: 0.5339 | Val loss: 0.5495 | Val Acc: 0.7697
# Epoch 085 | Train loss: 0.5329 | Val loss: 0.5491 | Val Acc: 0.7686
# Epoch 086 | Train loss: 0.5302 | Val loss: 0.5484 | Val Acc: 0.7680
# Epoch 087 | Train loss: 0.5315 | Val loss: 0.5480 | Val Acc: 0.7713
# Epoch 088 | Train loss: 0.5289 | Val loss: 0.5479 | Val Acc: 0.7669
# Epoch 089 | Train loss: 0.5292 | Val loss: 0.5473 | Val Acc: 0.7702
# Epoch 090 | Train loss: 0.5275 | Val loss: 0.5477 | Val Acc: 0.7678
# Epoch 091 | Train loss: 0.5263 | Val loss: 0.5464 | Val Acc: 0.7685
# Epoch 092 | Train loss: 0.5261 | Val loss: 0.5457 | Val Acc: 0.7723
# Epoch 093 | Train loss: 0.5244 | Val loss: 0.5459 | Val Acc: 0.7682
# Epoch 094 | Train loss: 0.5254 | Val loss: 0.5454 | Val Acc: 0.7707
# Epoch 095 | Train loss: 0.5256 | Val loss: 0.5451 | Val Acc: 0.7722
# Epoch 096 | Train loss: 0.5250 | Val loss: 0.5446 | Val Acc: 0.7691
# Epoch 097 | Train loss: 0.5198 | Val loss: 0.5444 | Val Acc: 0.7703
# Epoch 098 | Train loss: 0.5199 | Val loss: 0.5454 | Val Acc: 0.7695
# Epoch 099 | Train loss: 0.5198 | Val loss: 0.5453 | Val Acc: 0.7694
# Epoch 100 | Train loss: 0.5205 | Val loss: 0.5430 | Val Acc: 0.7714
# Epoch 101 | Train loss: 0.5192 | Val loss: 0.5436 | Val Acc: 0.7671
# Epoch 102 | Train loss: 0.5174 | Val loss: 0.5431 | Val Acc: 0.7705
# Epoch 103 | Train loss: 0.5207 | Val loss: 0.5437 | Val Acc: 0.7682
# Epoch 104 | Train loss: 0.5173 | Val loss: 0.5426 | Val Acc: 0.7701
# Epoch 105 | Train loss: 0.5162 | Val loss: 0.5427 | Val Acc: 0.7672
# Epoch 106 | Train loss: 0.5151 | Val loss: 0.5427 | Val Acc: 0.7707
# Epoch 107 | Train loss: 0.5134 | Val loss: 0.5415 | Val Acc: 0.7693
# Epoch 108 | Train loss: 0.5146 | Val loss: 0.5422 | Val Acc: 0.7677
# Epoch 109 | Train loss: 0.5165 | Val loss: 0.5415 | Val Acc: 0.7705
# Epoch 110 | Train loss: 0.5133 | Val loss: 0.5413 | Val Acc: 0.7704
# Epoch 111 | Train loss: 0.5136 | Val loss: 0.5410 | Val Acc: 0.7684
# Epoch 112 | Train loss: 0.5110 | Val loss: 0.5419 | Val Acc: 0.7685
# Epoch 113 | Train loss: 0.5092 | Val loss: 0.5407 | Val Acc: 0.7694
# Epoch 114 | Train loss: 0.5090 | Val loss: 0.5412 | Val Acc: 0.7719
# Epoch 115 | Train loss: 0.5101 | Val loss: 0.5407 | Val Acc: 0.7711
# Epoch 116 | Train loss: 0.5086 | Val loss: 0.5409 | Val Acc: 0.7681
# Epoch 117 | Train loss: 0.5077 | Val loss: 0.5413 | Val Acc: 0.7699
# Epoch 118 | Train loss: 0.5084 | Val loss: 0.5404 | Val Acc: 0.7744
# Epoch 119 | Train loss: 0.5092 | Val loss: 0.5397 | Val Acc: 0.7704
# Epoch 120 | Train loss: 0.5063 | Val loss: 0.5397 | Val Acc: 0.7754
# Epoch 121 | Train loss: 0.5068 | Val loss: 0.5396 | Val Acc: 0.7706
# Epoch 122 | Train loss: 0.5057 | Val loss: 0.5403 | Val Acc: 0.7685
# Epoch 123 | Train loss: 0.5057 | Val loss: 0.5406 | Val Acc: 0.7705
# Epoch 124 | Train loss: 0.5052 | Val loss: 0.5390 | Val Acc: 0.7710
# Epoch 125 | Train loss: 0.5017 | Val loss: 0.5390 | Val Acc: 0.7713
# Epoch 126 | Train loss: 0.5000 | Val loss: 0.5388 | Val Acc: 0.7704
# Epoch 127 | Train loss: 0.5001 | Val loss: 0.5386 | Val Acc: 0.7743
# Epoch 128 | Train loss: 0.4994 | Val loss: 0.5381 | Val Acc: 0.7697
# Epoch 129 | Train loss: 0.5002 | Val loss: 0.5380 | Val Acc: 0.7695
# Epoch 130 | Train loss: 0.4993 | Val loss: 0.5383 | Val Acc: 0.7704
# Epoch 131 | Train loss: 0.5006 | Val loss: 0.5385 | Val Acc: 0.7724
# Epoch 132 | Train loss: 0.4961 | Val loss: 0.5385 | Val Acc: 0.7713
# Epoch 133 | Train loss: 0.4958 | Val loss: 0.5386 | Val Acc: 0.7682
# Epoch 134 | Train loss: 0.4991 | Val loss: 0.5378 | Val Acc: 0.7682
# Epoch 135 | Train loss: 0.4951 | Val loss: 0.5377 | Val Acc: 0.7736
# Epoch 136 | Train loss: 0.4935 | Val loss: 0.5380 | Val Acc: 0.7702
# Epoch 137 | Train loss: 0.4954 | Val loss: 0.5374 | Val Acc: 0.7703
# Epoch 138 | Train loss: 0.4955 | Val loss: 0.5386 | Val Acc: 0.7683
# Epoch 139 | Train loss: 0.4938 | Val loss: 0.5377 | Val Acc: 0.7704
# Epoch 140 | Train loss: 0.4927 | Val loss: 0.5390 | Val Acc: 0.7684
# Epoch 141 | Train loss: 0.4933 | Val loss: 0.5378 | Val Acc: 0.7725
# Epoch 142 | Train loss: 0.4912 | Val loss: 0.5379 | Val Acc: 0.7692
# Epoch 143 | Train loss: 0.4904 | Val loss: 0.5391 | Val Acc: 0.7679
# Epoch 144 | Train loss: 0.4903 | Val loss: 0.5375 | Val Acc: 0.7739
# Epoch 145 | Train loss: 0.4886 | Val loss: 0.5376 | Val Acc: 0.7696
# Epoch 146 | Train loss: 0.4893 | Val loss: 0.5388 | Val Acc: 0.7711
# Epoch 147 | Train loss: 0.4878 | Val loss: 0.5362 | Val Acc: 0.7744
# Epoch 148 | Train loss: 0.4896 | Val loss: 0.5369 | Val Acc: 0.7719
# Epoch 149 | Train loss: 0.4888 | Val loss: 0.5371 | Val Acc: 0.7697
# Epoch 150 | Train loss: 0.4855 | Val loss: 0.5380 | Val Acc: 0.7724
# Training finished.
#
# Using model state from final epoch for evaluation.

# %%
model.eval()
fc.eval()

all_preds = []
all_true = []

with torch.no_grad():
    for Xb, yb in batches(X_test_seq, y_test_seq, BATCH_SIZE, shuffle=False):

        out, _ = model(Xb)              # (batch, seq_len, hidden)
        logits = fc(out)                # (batch, seq_len, num_classes)

        preds = logits.argmax(dim=2)    # (batch, seq_len)

        all_preds.append(preds.cpu())
        all_true.append(yb.cpu())

# Concatenate along batch dimension
y_pred = torch.cat(all_preds, dim=0).numpy()   # (N, seq_len)
y_true = torch.cat(all_true, dim=0).numpy()    # (N, seq_len)
# Flatten to (N * seq_len)
y_pred_flat = y_pred.reshape(-1)
y_true_flat = y_true.reshape(-1)

# Compute accuracy
acc = accuracy_score(y_true_flat, y_pred_flat)
print(f"Test Accuracy: {acc:.4f}")

print("\nClassification report:")
print(classification_report(y_true_flat, y_pred_flat))

# Confusion matrix
target_names = list(label_encoder.classes_)
cm = confusion_matrix(y_true_flat, y_pred_flat)

plt.figure(figsize=(6, 5))
plt.imshow(cm, interpolation='nearest', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.xticks(ticks=np.arange(len(target_names)), labels=target_names, rotation=45, ha='right')
plt.yticks(ticks=np.arange(len(target_names)), labels=target_names)

# Annotate each cell
for (i, j), v in np.ndenumerate(cm):
    plt.text(j, i, str(v), ha='center', va='center', color='black')

plt.tight_layout()
plt.show()
# Out:
# Test Accuracy: 0.7851
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.73      0.84      0.78       391
#            1       0.85      0.88      0.87       366
#            2       0.94      0.78      0.85      1422
#            3       0.32      0.56      0.41       231
#
#     accuracy                           0.79      2410
#    macro avg       0.71      0.77      0.73      2410
# weighted avg       0.83      0.79      0.80      2410

# %%
### stable gear test

ALL_LABELS = list(range(num_classes))
n=2

y_true_series = pd.Series(y_true_flat)

stable_acc = accuracy_when_stable_gear(y_true_series, y_pred_flat, n=n)
print(f"\nStable-gear accuracy (n=2): {stable_acc:.4f}")

print("\nClassification report on stable segments:")
print(classification_report_when_stable_gear(y_true_series, y_pred_flat, n=n))

cm_stable = confusion_matrix_when_stable_gear(y_true_series, y_pred_flat, n=n)

if cm_stable is not None:
    plt.figure(figsize=(6, 5))
    plt.imshow(cm_stable, interpolation='nearest', cmap='Blues')
    plt.title('Confusion Matrix (Stable Gear Only)')
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.xticks(ticks=np.arange(len(target_names)), labels=target_names, rotation=45, ha='right')
    plt.yticks(ticks=np.arange(len(target_names)), labels=target_names)

    for (i, j), v in np.ndenumerate(cm_stable):
        plt.text(j, i, str(v), ha='center', va='center', color='black')

    plt.tight_layout()
    plt.show()
else:
    print("No stable segments found for confusion matrix.")
# Out:
# Stable-gear accuracy (n=2): 0.8415
#
# Classification report on stable segments:
#               precision    recall  f1-score   support
#
#            0       0.85      0.91      0.88       311
#            1       0.92      0.93      0.92       320
#            2       0.96      0.82      0.89      1306
#            3       0.29      0.67      0.41       126
#
#     accuracy                           0.84      2063
#    macro avg       0.75      0.83      0.77      2063
# weighted avg       0.90      0.84      0.86      2063

# %%
import matplotlib.patches as mpatches

# 1. Align Data
# Since the model consumes a sequence (SEQ_LEN) to predict the label at the last step,
# we must align the Time/Altitude data by slicing off the first (SEQ_LEN - 1) frames.
# Note: We assume STEP=1. If STEP > 1, slicing would be test_df.iloc[SEQ_LEN-1::STEP]

cutoff = SEQ_LEN - 1

# Try to find a Time column, otherwise use index
time_col = 'Time' if 'Time' in test_df.columns else None
if time_col:
    t = test_df[time_col].values[cutoff:]
else:
    print("Warning: 'Time' column not found. Using DataFrame index.")
    t = test_df.index.values[cutoff:]

alt = test_df['ns1:AltitudeMeters'].values[cutoff:]

# Ensure lengths match exactly (handle potential off-by-one errors in edge cases)
min_len = min(len(t), len(y_pred_flat), len(y_true_flat))
t = t[:min_len]
alt = alt[:min_len]
pred_int = np.array(y_pred_flat)[:min_len]
true_int = np.array(y_true_flat)[:min_len]

# 2. Decode Labels (Integers -> Original Strings)
# We map integers back to original labels (e.g., 0 -> 'Gear 2') for the legend
pred_str = label_encoder.inverse_transform(pred_int)
true_str = label_encoder.inverse_transform(true_int)
unique_classes_str = label_encoder.classes_

# 3. Setup Colors
# Create a consistent color map for the classes
cmap = plt.get_cmap("tab10")
class_to_color = {cls_name: cmap(i) for i, cls_name in enumerate(unique_classes_str)}

# 4. Plotting
plt.figure(figsize=(16, 8))

# A. Plot Altitude
# Calculate dynamic y-positions for the bands based on altitude range
y_min, y_max = alt.min(), alt.max()
y_range = y_max - y_min

# Band positions (placed slightly below the minimum altitude)
true_band_top = y_min - (0.05 * y_range)
true_band_bot = y_min - (0.15 * y_range)
pred_band_top = y_min - (0.18 * y_range)
pred_band_bot = y_min - (0.28 * y_range)

# B. Plot TRUE Gear Band
# We iterate through unique classes to fill sections
for cls_name in unique_classes_str:
    mask = (true_str == cls_name)
    if np.any(mask):
        plt.fill_between(
            t, true_band_bot, true_band_top,
            where=mask,
            color=class_to_color[cls_name],
            alpha=0.6,
            step='mid' # Important for discrete steps
        )

# C. Plot PREDICTED Gear Band
for cls_name in unique_classes_str:
    mask = (pred_str == cls_name)
    if np.any(mask):
        plt.fill_between(
            t, pred_band_bot, pred_band_top,
            where=mask,
            color=class_to_color[cls_name],
            alpha=0.6,
            step='mid'
        )

# D. Formatting & Legend
plt.xlabel("Time" if time_col else "Frame Index")
plt.title("(Top Band: True | Bottom Band: Predicted)")

# Create custom legend handles
handles = [mpatches.Patch(color=class_to_color[c], label=f"Gear {c}") for c in unique_classes_str]
handles.append(plt.Line2D([], [], color='black', label='Altitude'))

plt.legend(handles=handles, loc="upper right")
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# Warning: 'Time' column not found. Using DataFrame index.

# %%
# Out:
# 0       0.238836
# 1       0.238836
# 2       0.356428
# 3       0.335048
# 4       0.420570
#           ...
# 2414    0.313667
# 2415    0.377809
# 2416    0.313667
# 2417    0.131933
# 2418   -0.049802
# Name: speed_kmph, Length: 2419, dtype: float64
